# %% [markdown]
# <a href="https://colab.research.google.com/github/seuch98/Data-Analysis-Term-Project/blob/main/epoch_%EC%8B%A4%ED%97%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **처음 돌리고 다시 돌리지 말것!**
# 다시 돌리면 데이터 변경되므로 같은 데이터에 대해 실험하기 위해선 아래 셀은 다시 실행 X

# %%
import pandas as pd
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

#dataset_path = 'fer2013.csv'
dataset_path = '/content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/참고 코드/challenges-in-representation-learning-facial-expression-recognition-challenge/fer2013/fer2013/fer2013.csv'
image_size=(48,48)

#csv 파일 읽어서 48*48 크기의 이미지에서 각 행의 픽셀 시퀀스 변환. 얼굴과 감정 레이블 반환

def load_fer2013():
    data = pd.read_csv(dataset_path)
    pixels = data['pixels'].tolist()
    width, height = 48, 48
    faces = []
    for pixel_sequence in pixels:
        face = [int(pixel) for pixel in pixel_sequence.split(' ')]
        face = np.asarray(face).reshape(width, height)
        face = cv2.resize(face.astype('uint8'),image_size)
        faces.append(face.astype('float32'))
    faces = np.asarray(faces)
    faces = np.expand_dims(faces, -1)
    emotions = pd.get_dummies(data['emotion']).values
    return faces, emotions

#이미지를 -1에서 1 사이의 크기로 조정하여 이미지를 전처리하는 표준 방법.
#이미지의 크기를 [0,1]로 255 나눠서 조정.
#0.5를 빼고 2를 곱하면 범위가 [-1,1]로 바뀜. 이건 컴퓨터 비전 문제에서 신경 네트워크 모델에 대한 더 나은 범위

def preprocess_input(x, v2=True):
    x = x.astype('float32') #######
    x = x / 255.0
    if v2:
        x = x - 0.5
        x = x * 2.0
    return x
 
faces, emotions = load_fer2013()
faces = preprocess_input(faces)
xtrain, xtest,ytrain,ytest = train_test_split(faces, emotions,test_size=0.2,shuffle=True, random_state = 1004)

# %% [markdown]
# **이 부분만 다시 돌려서 실험 진행**

# %%
from keras.callbacks import CSVLogger, ModelCheckpoint, EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from keras.layers import Activation, Convolution2D, Dropout, Conv2D
from keras.layers import AveragePooling2D, BatchNormalization
from keras.layers import GlobalAveragePooling2D
from keras.models import Sequential
from keras.layers import Flatten
from keras.models import Model
from keras.layers import Input
from keras.layers import MaxPooling2D
from keras.layers import SeparableConv2D
from keras import layers
from keras.regularizers import l2
import pandas as pd
import cv2
import numpy as np
 
# parameters
batch_size = 32
num_epochs = 100 ####이 부분을 10부터 100까지 순서대로 변경하여 실험 진행
input_shape = (48, 48, 1)
verbose = 1
num_classes = 7
patience = 50
base_path = '/content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/epoch 실험/10/'
#base_path = './models/'
l2_regularization=0.01
 
# data generator
data_generator = ImageDataGenerator(
                        featurewise_center=False,
                        featurewise_std_normalization=False,
                        rotation_range=10,
                        width_shift_range=0.1,
                        height_shift_range=0.1,
                        zoom_range=.1,
                        horizontal_flip=True)
 
# model parameters
regularization = l2(l2_regularization)
 
# base
img_input = Input(input_shape)
x = Conv2D(8, (3, 3), strides=(1, 1), kernel_regularizer=regularization, use_bias=False)(img_input)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Conv2D(8, (3, 3), strides=(1, 1), kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
 
# module 1
residual = Conv2D(16, (1, 1), strides=(2, 2), padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(16, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(16, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
 
# module 2
residual = Conv2D(32, (1, 1), strides=(2, 2), padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(32, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(32, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
 
# module 3
residual = Conv2D(64, (1, 1), strides=(2, 2),padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(64, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(64, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
 
# module 4
residual = Conv2D(128, (1, 1), strides=(2, 2),padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(128, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(128, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
x = Conv2D(num_classes, (3, 3), padding='same')(x)
x = GlobalAveragePooling2D()(x)
output = Activation('softmax',name='predictions')(x)
 
model = Model(img_input, output)
model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
 
# callbacks
log_file_path = base_path + '_emotion_training.log'
csv_logger = CSVLogger(log_file_path, append=False)
early_stop = EarlyStopping('val_loss', patience=patience)
reduce_lr = ReduceLROnPlateau('val_loss', factor=0.1, patience=int(patience/4), verbose=1)
trained_models_path = base_path + '_mini_XCEPTION'
model_names = trained_models_path + '.{epoch:02d}-{val_accuracy:.2f}.hdf5'
model_checkpoint = ModelCheckpoint(model_names, 'val_loss', verbose=1,save_best_only=True)
callbacks = [model_checkpoint, csv_logger, early_stop, reduce_lr]
 
history= model.fit_generator(data_generator.flow(xtrain, ytrain,batch_size),
                        steps_per_epoch=len(xtrain) / batch_size,
                        epochs=num_epochs, verbose=1, callbacks=callbacks,
                        validation_data=(xtest,ytest))
# Out:
# Model: "functional_19"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           [(None, 48, 48, 1)]  0
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 46, 46, 8)    72          input_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 46, 46, 8)    32          conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 46, 46, 8)    0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 44, 44, 8)    576         activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 44, 44, 8)    32          conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 44, 44, 8)    0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_72 (SeparableC (None, 44, 44, 16)   200         activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 44, 44, 16)   64          separable_conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 44, 44, 16)   0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_73 (SeparableC (None, 44, 44, 16)   400         activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 44, 44, 16)   64          separable_conv2d_73[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 22, 22, 16)   128         activation_55[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_36 (MaxPooling2D) (None, 22, 22, 16)   0           batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 22, 22, 16)   64          conv2d_65[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 22, 22, 16)   0           max_pooling2d_36[0][0]
#                                                                  batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_74 (SeparableC (None, 22, 22, 32)   656         add_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 22, 22, 32)   128         separable_conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 22, 22, 32)   0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_75 (SeparableC (None, 22, 22, 32)   1312        activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 22, 22, 32)   128         separable_conv2d_75[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 11, 11, 32)   512         add_36[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_37 (MaxPooling2D) (None, 11, 11, 32)   0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 11, 11, 32)   128         conv2d_66[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 11, 11, 32)   0           max_pooling2d_37[0][0]
#                                                                  batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_76 (SeparableC (None, 11, 11, 64)   2336        add_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 11, 11, 64)   256         separable_conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 11, 11, 64)   0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_77 (SeparableC (None, 11, 11, 64)   4672        activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 11, 11, 64)   256         separable_conv2d_77[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 6, 6, 64)     2048        add_37[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_38 (MaxPooling2D) (None, 6, 6, 64)     0           batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 6, 6, 64)     256         conv2d_67[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 6, 6, 64)     0           max_pooling2d_38[0][0]
#                                                                  batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_78 (SeparableC (None, 6, 6, 128)    8768        add_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 6, 6, 128)    512         separable_conv2d_78[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 6, 6, 128)    0           batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_79 (SeparableC (None, 6, 6, 128)    17536       activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 6, 6, 128)    512         separable_conv2d_79[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 3, 3, 128)    8192        add_38[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_39 (MaxPooling2D) (None, 3, 3, 128)    0           batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 3, 3, 128)    512         conv2d_68[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 3, 3, 128)    0           max_pooling2d_39[0][0]
#                                                                  batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 3, 3, 7)      8071        add_39[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 7)            0           conv2d_69[0][0]
# __________________________________________________________________________________________________
# predictions (Activation)        (None, 7)            0           global_average_pooling2d_9[0][0]
# ==================================================================================================
# Total params: 58,423
# Trainable params: 56,951
# Non-trainable params: 1,472
# __________________________________________________________________________________________________
# Epoch 1/100
# 897/897 [============================>.] - ETA: 0s - loss: 1.7836 - accuracy: 0.3227
# Epoch 00001: val_loss improved from inf to 1.65461, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/epoch 실험/10/_mini_XCEPTION.01-0.40.hdf5
# 898/897 [==============================] - 31s 35ms/step - loss: 1.7836 - accuracy: 0.3226 - val_loss: 1.6546 - val_accuracy: 0.3955
# Epoch 2/100
# 897/897 [============================>.] - ETA: 0s - loss: 1.5165 - accuracy: 0.4318
# Epoch 00002: val_loss improved from 1.65461 to 1.46756, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/epoch 실험/10/_mini_XCEPTION.02-0.47.hdf5
# 898/897 [==============================] - 31s 34ms/step - loss: 1.5164 - accuracy: 0.4319 - val_loss: 1.4676 - val_accuracy: 0.4677
# Epoch 3/100
# 898/897 [==============================] - ETA: 0s - loss: 1.4055 - accuracy: 0.4725
# Epoch 00003: val_loss did not improve from 1.46756
# 898/897 [==============================] - 31s 34ms/step - loss: 1.4055 - accuracy: 0.4725 - val_loss: 1.4713 - val_accuracy: 0.4418
# Epoch 4/100
# 898/897 [==============================] - ETA: 0s - loss: 1.3352 - accuracy: 0.5003
# Epoch 00004: val_loss improved from 1.46756 to 1.25819, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/epoch 실험/10/_mini_XCEPTION.04-0.54.hdf5
# 898/897 [==============================] - 30s 33ms/step - loss: 1.3352 - accuracy: 0.5003 - val_loss: 1.2582 - val_accuracy: 0.5450
# Epoch 5/100
# 898/897 [==============================] - ETA: 0s - loss: 1.2984 - accuracy: 0.5105
# Epoch 00005: val_loss did not improve from 1.25819
# 898/897 [==============================] - 30s 33ms/step - loss: 1.2984 - accuracy: 0.5105 - val_loss: 1.3030 - val_accuracy: 0.5189
# Epoch 6/100
# 897/897 [============================>.] - ETA: 0s - loss: 1.2596 - accuracy: 0.5283
# Epoch 00006: val_loss improved from 1.25819 to 1.22644, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/epoch 실험/10/_mini_XCEPTION.06-0.54.hdf5
# 898/897 [==============================] - 30s 34ms/step - loss: 1.2592 - accuracy: 0.5285 - val_loss: 1.2264 - val_accuracy: 0.5436
# Epoch 7/100
# 897/897 [============================>.] - ETA: 0s - loss: 1.2335 - accuracy: 0.5380
# Epoch 00007: val_loss did not improve from 1.22644
# 898/897 [==============================] - 31s 34ms/step - loss: 1.2332 - accuracy: 0.5381 - val_loss: 1.2691 - val_accuracy: 0.5251
# Epoch 8/100
# 898/897 [==============================] - ETA: 0s - loss: 1.2014 - accuracy: 0.5481
# Epoch 00008: val_loss improved from 1.22644 to 1.20821, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/epoch 실험/10/_mini_XCEPTION.08-0.55.hdf5
# 898/897 [==============================] - 30s 34ms/step - loss: 1.2014 - accuracy: 0.5481 - val_loss: 1.2082 - val_accuracy: 0.5549
# Epoch 9/100
# 898/897 [==============================] - ETA: 0s - loss: 1.1900 - accuracy: 0.5516
# Epoch 00009: val_loss improved from 1.20821 to 1.20120, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/epoch 실험/10/_mini_XCEPTION.09-0.56.hdf5
# 898/897 [==============================] - 31s 34ms/step - loss: 1.1900 - accuracy: 0.5516 - val_loss: 1.2012 - val_accuracy: 0.5589
# Epoch 10/100
# 898/897 [==============================] - ETA: 0s - loss: 1.1706 - accuracy: 0.5619
# Epoch 00010: val_loss improved from 1.20120 to 1.19979, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/epoch 실험/10/_mini_XCEPTION.10-0.54.hdf5
# 898/897 [==============================] - 31s 35ms/step - loss: 1.1706 - accuracy: 0.5619 - val_loss: 1.1998 - val_accuracy: 0.5442
# Epoch 11/100
# 897/897 [============================>.] - ETA: 0s - loss: 1.1535 - accuracy: 0.5668
# Epoch 00011: val_loss did not improve from 1.19979
# 898/897 [==============================] - 30s 33ms/step - loss: 1.1535 - accuracy: 0.5667 - val_loss: 1.3228 - val_accuracy: 0.4937
# Epoch 12/100
# 898/897 [==============================] - ETA: 0s - loss: 1.1378 - accuracy: 0.5741
# Epoch 00012: val_loss improved from 1.19979 to 1.14076, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/epoch 실험/10/_mini_XCEPTION.12-0.57.hdf5
# 898/897 [==============================] - 30s 34ms/step - loss: 1.1378 - accuracy: 0.5741 - val_loss: 1.1408 - val_accuracy: 0.5678
# Epoch 13/100
# 898/897 [==============================] - ETA: 0s - loss: 1.1260 - accuracy: 0.5790
# Epoch 00013: val_loss improved from 1.14076 to 1.12154, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/epoch 실험/10/_mini_XCEPTION.13-0.59.hdf5
# 898/897 [==============================] - 31s 34ms/step - loss: 1.1260 - accuracy: 0.5790 - val_loss: 1.1215 - val_accuracy: 0.5901
# Epoch 14/100
# 897/897 [============================>.] - ETA: 0s - loss: 1.1156 - accuracy: 0.5841
# Epoch 00014: val_loss did not improve from 1.12154
# 898/897 [==============================] - 30s 33ms/step - loss: 1.1156 - accuracy: 0.5840 - val_loss: 1.1529 - val_accuracy: 0.5646
# Epoch 15/100
# 897/897 [============================>.] - ETA: 0s - loss: 1.1032 - accuracy: 0.5850
# Epoch 00015: val_loss did not improve from 1.12154
# 898/897 [==============================] - 30s 34ms/step - loss: 1.1030 - accuracy: 0.5850 - val_loss: 1.1403 - val_accuracy: 0.5740
# Epoch 16/100
# 897/897 [============================>.] - ETA: 0s - loss: 1.1003 - accuracy: 0.5848
# Epoch 00016: val_loss improved from 1.12154 to 1.11719, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/epoch 실험/10/_mini_XCEPTION.16-0.58.hdf5
# 898/897 [==============================] - 30s 34ms/step - loss: 1.1003 - accuracy: 0.5848 - val_loss: 1.1172 - val_accuracy: 0.5837
# Epoch 17/100
# 897/897 [============================>.] - ETA: 0s - loss: 1.0861 - accuracy: 0.5930
# Epoch 00017: val_loss improved from 1.11719 to 1.07761, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/epoch 실험/10/_mini_XCEPTION.17-0.60.hdf5
# 898/897 [==============================] - 30s 34ms/step - loss: 1.0858 - accuracy: 0.5932 - val_loss: 1.0776 - val_accuracy: 0.5988
# Epoch 18/100
# 897/897 [============================>.] - ETA: 0s - loss: 1.0749 - accuracy: 0.5963
# Epoch 00018: val_loss did not improve from 1.07761
# 898/897 [==============================] - 30s 33ms/step - loss: 1.0749 - accuracy: 0.5962 - val_loss: 1.1207 - val_accuracy: 0.5766
# Epoch 19/100
# 898/897 [==============================] - ETA: 0s - loss: 1.0723 - accuracy: 0.5984
# Epoch 00019: val_loss did not improve from 1.07761
# 898/897 [==============================] - 30s 33ms/step - loss: 1.0723 - accuracy: 0.5984 - val_loss: 1.0934 - val_accuracy: 0.5938
# Epoch 20/100
# 898/897 [==============================] - ETA: 0s - loss: 1.0684 - accuracy: 0.5980
# Epoch 00020: val_loss did not improve from 1.07761
# 898/897 [==============================] - 30s 33ms/step - loss: 1.0684 - accuracy: 0.5980 - val_loss: 1.0882 - val_accuracy: 0.6055
# Epoch 21/100
# 898/897 [==============================] - ETA: 0s - loss: 1.0612 - accuracy: 0.6036
# Epoch 00021: val_loss did not improve from 1.07761
# 898/897 [==============================] - 30s 33ms/step - loss: 1.0612 - accuracy: 0.6036 - val_loss: 1.1211 - val_accuracy: 0.5890
# Epoch 22/100
# 897/897 [============================>.] - ETA: 0s - loss: 1.0547 - accuracy: 0.6037
# Epoch 00022: val_loss improved from 1.07761 to 1.07423, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/epoch 실험/10/_mini_XCEPTION.22-0.60.hdf5
# 898/897 [==============================] - 30s 33ms/step - loss: 1.0548 - accuracy: 0.6036 - val_loss: 1.0742 - val_accuracy: 0.5982
# Epoch 23/100
# 897/897 [============================>.] - ETA: 0s - loss: 1.0438 - accuracy: 0.6101
# Epoch 00023: val_loss improved from 1.07423 to 1.06443, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/epoch 실험/10/_mini_XCEPTION.23-0.61.hdf5
# 898/897 [==============================] - 30s 33ms/step - loss: 1.0438 - accuracy: 0.6102 - val_loss: 1.0644 - val_accuracy: 0.6096
# Epoch 24/100
# 898/897 [==============================] - ETA: 0s - loss: 1.0405 - accuracy: 0.6119
# Epoch 00024: val_loss did not improve from 1.06443
# 898/897 [==============================] - 30s 33ms/step - loss: 1.0405 - accuracy: 0.6119 - val_loss: 1.0956 - val_accuracy: 0.6002
# Epoch 25/100
# 897/897 [============================>.] - ETA: 0s - loss: 1.0378 - accuracy: 0.6134
# Epoch 00025: val_loss did not improve from 1.06443
# 898/897 [==============================] - 30s 33ms/step - loss: 1.0377 - accuracy: 0.6133 - val_loss: 1.0971 - val_accuracy: 0.5921
# Epoch 26/100
# 897/897 [============================>.] - ETA: 0s - loss: 1.0339 - accuracy: 0.6143
# Epoch 00026: val_loss improved from 1.06443 to 1.04966, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/epoch 실험/10/_mini_XCEPTION.26-0.61.hdf5
# 898/897 [==============================] - 30s 33ms/step - loss: 1.0338 - accuracy: 0.6142 - val_loss: 1.0497 - val_accuracy: 0.6123
# Epoch 27/100
# 897/897 [============================>.] - ETA: 0s - loss: 1.0279 - accuracy: 0.6154
# Epoch 00027: val_loss did not improve from 1.04966
# 898/897 [==============================] - 30s 33ms/step - loss: 1.0276 - accuracy: 0.6154 - val_loss: 1.0559 - val_accuracy: 0.6073
# Epoch 28/100
# 898/897 [==============================] - ETA: 0s - loss: 1.0203 - accuracy: 0.6196
# Epoch 00028: val_loss did not improve from 1.04966
# 898/897 [==============================] - 30s 33ms/step - loss: 1.0203 - accuracy: 0.6196 - val_loss: 1.0555 - val_accuracy: 0.6106
# Epoch 29/100
# 897/897 [============================>.] - ETA: 0s - loss: 1.0185 - accuracy: 0.6199
# Epoch 00029: val_loss did not improve from 1.04966
# 898/897 [==============================] - 29s 33ms/step - loss: 1.0183 - accuracy: 0.6200 - val_loss: 1.0682 - val_accuracy: 0.6063
# Epoch 30/100
# 898/897 [==============================] - ETA: 0s - loss: 1.0124 - accuracy: 0.6210
# Epoch 00030: val_loss did not improve from 1.04966
# 898/897 [==============================] - 30s 33ms/step - loss: 1.0124 - accuracy: 0.6210 - val_loss: 1.0530 - val_accuracy: 0.6098
# Epoch 31/100
# 898/897 [==============================] - ETA: 0s - loss: 1.0112 - accuracy: 0.6224
# Epoch 00031: val_loss did not improve from 1.04966
# 898/897 [==============================] - 30s 33ms/step - loss: 1.0112 - accuracy: 0.6224 - val_loss: 1.0670 - val_accuracy: 0.6071
# Epoch 32/100
# 897/897 [============================>.] - ETA: 0s - loss: 1.0079 - accuracy: 0.6227
# Epoch 00032: val_loss did not improve from 1.04966
# 898/897 [==============================] - 30s 33ms/step - loss: 1.0081 - accuracy: 0.6227 - val_loss: 1.0993 - val_accuracy: 0.5945
# Epoch 33/100
# 897/897 [============================>.] - ETA: 0s - loss: 1.0018 - accuracy: 0.6286
# Epoch 00033: val_loss did not improve from 1.04966
# 898/897 [==============================] - 30s 33ms/step - loss: 1.0022 - accuracy: 0.6284 - val_loss: 1.0857 - val_accuracy: 0.6009
# Epoch 34/100
# 898/897 [==============================] - ETA: 0s - loss: 0.9939 - accuracy: 0.6290
# Epoch 00034: val_loss did not improve from 1.04966
# 898/897 [==============================] - 30s 33ms/step - loss: 0.9939 - accuracy: 0.6290 - val_loss: 1.0827 - val_accuracy: 0.6010
# Epoch 35/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.9956 - accuracy: 0.6266
# Epoch 00035: val_loss improved from 1.04966 to 1.02675, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/epoch 실험/10/_mini_XCEPTION.35-0.62.hdf5
# 898/897 [==============================] - 30s 33ms/step - loss: 0.9959 - accuracy: 0.6264 - val_loss: 1.0268 - val_accuracy: 0.6247
# Epoch 36/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.9941 - accuracy: 0.6282
# Epoch 00036: val_loss did not improve from 1.02675
# 898/897 [==============================] - 30s 33ms/step - loss: 0.9940 - accuracy: 0.6282 - val_loss: 1.0563 - val_accuracy: 0.6159
# Epoch 37/100
# 898/897 [==============================] - ETA: 0s - loss: 0.9865 - accuracy: 0.6327
# Epoch 00037: val_loss did not improve from 1.02675
# 898/897 [==============================] - 30s 33ms/step - loss: 0.9865 - accuracy: 0.6327 - val_loss: 1.0573 - val_accuracy: 0.6141
# Epoch 38/100
# 898/897 [==============================] - ETA: 0s - loss: 0.9827 - accuracy: 0.6327
# Epoch 00038: val_loss did not improve from 1.02675
# 898/897 [==============================] - 30s 33ms/step - loss: 0.9827 - accuracy: 0.6327 - val_loss: 1.0555 - val_accuracy: 0.6103
# Epoch 39/100
# 898/897 [==============================] - ETA: 0s - loss: 0.9817 - accuracy: 0.6319
# Epoch 00039: val_loss did not improve from 1.02675
# 898/897 [==============================] - 30s 33ms/step - loss: 0.9817 - accuracy: 0.6319 - val_loss: 1.0593 - val_accuracy: 0.6089
# Epoch 40/100
# 898/897 [==============================] - ETA: 0s - loss: 0.9823 - accuracy: 0.6353
# Epoch 00040: val_loss improved from 1.02675 to 1.01940, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/epoch 실험/10/_mini_XCEPTION.40-0.62.hdf5
# 898/897 [==============================] - 30s 34ms/step - loss: 0.9823 - accuracy: 0.6353 - val_loss: 1.0194 - val_accuracy: 0.6176
# Epoch 41/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.9727 - accuracy: 0.6369
# Epoch 00041: val_loss did not improve from 1.01940
# 898/897 [==============================] - 30s 33ms/step - loss: 0.9727 - accuracy: 0.6369 - val_loss: 1.0499 - val_accuracy: 0.6119
# Epoch 42/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.9702 - accuracy: 0.6390
# Epoch 00042: val_loss did not improve from 1.01940
# 898/897 [==============================] - 30s 34ms/step - loss: 0.9700 - accuracy: 0.6390 - val_loss: 1.0320 - val_accuracy: 0.6183
# Epoch 43/100
# 898/897 [==============================] - ETA: 0s - loss: 0.9708 - accuracy: 0.6398
# Epoch 00043: val_loss did not improve from 1.01940
# 898/897 [==============================] - 30s 34ms/step - loss: 0.9708 - accuracy: 0.6398 - val_loss: 1.0609 - val_accuracy: 0.6134
# Epoch 44/100
# 898/897 [==============================] - ETA: 0s - loss: 0.9671 - accuracy: 0.6397
# Epoch 00044: val_loss did not improve from 1.01940
# 898/897 [==============================] - 30s 33ms/step - loss: 0.9671 - accuracy: 0.6397 - val_loss: 1.0945 - val_accuracy: 0.5996
# Epoch 45/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.9696 - accuracy: 0.6371
# Epoch 00045: val_loss did not improve from 1.01940
# 898/897 [==============================] - 30s 33ms/step - loss: 0.9698 - accuracy: 0.6370 - val_loss: 1.0299 - val_accuracy: 0.6293
# Epoch 46/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.9568 - accuracy: 0.6475
# Epoch 00046: val_loss did not improve from 1.01940
# 898/897 [==============================] - 30s 33ms/step - loss: 0.9565 - accuracy: 0.6476 - val_loss: 1.0955 - val_accuracy: 0.6027
# Epoch 47/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.9603 - accuracy: 0.6419
# Epoch 00047: val_loss did not improve from 1.01940
# 898/897 [==============================] - 30s 34ms/step - loss: 0.9603 - accuracy: 0.6420 - val_loss: 1.0421 - val_accuracy: 0.6225
# Epoch 48/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.9556 - accuracy: 0.6431
# Epoch 00048: val_loss did not improve from 1.01940
# 898/897 [==============================] - 30s 34ms/step - loss: 0.9554 - accuracy: 0.6431 - val_loss: 1.0807 - val_accuracy: 0.6053
# Epoch 49/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.9561 - accuracy: 0.6456
# Epoch 00049: val_loss did not improve from 1.01940
# 898/897 [==============================] - 30s 34ms/step - loss: 0.9560 - accuracy: 0.6457 - val_loss: 1.1082 - val_accuracy: 0.5928
# Epoch 50/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.9512 - accuracy: 0.6446
# Epoch 00050: val_loss did not improve from 1.01940
# 898/897 [==============================] - 30s 33ms/step - loss: 0.9511 - accuracy: 0.6447 - val_loss: 1.1280 - val_accuracy: 0.5943
# Epoch 51/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.9500 - accuracy: 0.6449
# Epoch 00051: val_loss did not improve from 1.01940
# 898/897 [==============================] - 30s 33ms/step - loss: 0.9498 - accuracy: 0.6450 - val_loss: 1.0397 - val_accuracy: 0.6195
# Epoch 52/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.9510 - accuracy: 0.6494
# Epoch 00052: val_loss did not improve from 1.01940
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 898/897 [==============================] - 30s 34ms/step - loss: 0.9510 - accuracy: 0.6494 - val_loss: 1.0508 - val_accuracy: 0.6194
# Epoch 53/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.8968 - accuracy: 0.6679
# Epoch 00053: val_loss improved from 1.01940 to 0.97806, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/epoch 실험/10/_mini_XCEPTION.53-0.64.hdf5
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8968 - accuracy: 0.6679 - val_loss: 0.9781 - val_accuracy: 0.6392
# Epoch 54/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8858 - accuracy: 0.6706
# Epoch 00054: val_loss did not improve from 0.97806
# 898/897 [==============================] - 30s 33ms/step - loss: 0.8858 - accuracy: 0.6706 - val_loss: 0.9798 - val_accuracy: 0.6383
# Epoch 55/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.8807 - accuracy: 0.6743
# Epoch 00055: val_loss did not improve from 0.97806
# 898/897 [==============================] - 30s 33ms/step - loss: 0.8808 - accuracy: 0.6742 - val_loss: 0.9789 - val_accuracy: 0.6425
# Epoch 56/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.8776 - accuracy: 0.6767
# Epoch 00056: val_loss improved from 0.97806 to 0.97166, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/epoch 실험/10/_mini_XCEPTION.56-0.64.hdf5
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8776 - accuracy: 0.6767 - val_loss: 0.9717 - val_accuracy: 0.6438
# Epoch 57/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.8728 - accuracy: 0.6739
# Epoch 00057: val_loss did not improve from 0.97166
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8729 - accuracy: 0.6739 - val_loss: 0.9729 - val_accuracy: 0.6446
# Epoch 58/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.8667 - accuracy: 0.6774
# Epoch 00058: val_loss did not improve from 0.97166
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8666 - accuracy: 0.6774 - val_loss: 0.9732 - val_accuracy: 0.6417
# Epoch 59/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.8683 - accuracy: 0.6782
# Epoch 00059: val_loss did not improve from 0.97166
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8681 - accuracy: 0.6783 - val_loss: 0.9790 - val_accuracy: 0.6428
# Epoch 60/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8656 - accuracy: 0.6796
# Epoch 00060: val_loss did not improve from 0.97166
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8656 - accuracy: 0.6796 - val_loss: 0.9763 - val_accuracy: 0.6417
# Epoch 61/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.8680 - accuracy: 0.6768
# Epoch 00061: val_loss did not improve from 0.97166
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8679 - accuracy: 0.6769 - val_loss: 0.9725 - val_accuracy: 0.6443
# Epoch 62/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.8593 - accuracy: 0.6785
# Epoch 00062: val_loss did not improve from 0.97166
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8594 - accuracy: 0.6785 - val_loss: 0.9785 - val_accuracy: 0.6457
# Epoch 63/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8579 - accuracy: 0.6802
# Epoch 00063: val_loss did not improve from 0.97166
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8579 - accuracy: 0.6802 - val_loss: 0.9828 - val_accuracy: 0.6429
# Epoch 64/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.8548 - accuracy: 0.6816
# Epoch 00064: val_loss did not improve from 0.97166
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8548 - accuracy: 0.6816 - val_loss: 0.9844 - val_accuracy: 0.6424
# Epoch 65/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.8586 - accuracy: 0.6806
# Epoch 00065: val_loss did not improve from 0.97166
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8589 - accuracy: 0.6804 - val_loss: 0.9800 - val_accuracy: 0.6422
# Epoch 66/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8568 - accuracy: 0.6847
# Epoch 00066: val_loss did not improve from 0.97166
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8568 - accuracy: 0.6847 - val_loss: 0.9818 - val_accuracy: 0.6403
# Epoch 67/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8570 - accuracy: 0.6823
# Epoch 00067: val_loss did not improve from 0.97166
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8570 - accuracy: 0.6823 - val_loss: 0.9818 - val_accuracy: 0.6429
# Epoch 68/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.8561 - accuracy: 0.6809
# Epoch 00068: val_loss did not improve from 0.97166
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8562 - accuracy: 0.6808 - val_loss: 0.9784 - val_accuracy: 0.6463
# Epoch 69/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8460 - accuracy: 0.6863
# Epoch 00069: val_loss did not improve from 0.97166
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8460 - accuracy: 0.6863 - val_loss: 0.9760 - val_accuracy: 0.6475
# Epoch 70/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.8463 - accuracy: 0.6846
# Epoch 00070: val_loss did not improve from 0.97166
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8463 - accuracy: 0.6847 - val_loss: 0.9751 - val_accuracy: 0.6474
# Epoch 71/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8461 - accuracy: 0.6866
# Epoch 00071: val_loss did not improve from 0.97166
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8461 - accuracy: 0.6866 - val_loss: 0.9759 - val_accuracy: 0.6463
# Epoch 72/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8422 - accuracy: 0.6897
# Epoch 00072: val_loss did not improve from 0.97166
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8422 - accuracy: 0.6897 - val_loss: 0.9757 - val_accuracy: 0.6467
# Epoch 73/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8436 - accuracy: 0.6861
# Epoch 00073: val_loss did not improve from 0.97166
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8436 - accuracy: 0.6861 - val_loss: 0.9776 - val_accuracy: 0.6470
# Epoch 74/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.8471 - accuracy: 0.6855
# Epoch 00074: val_loss did not improve from 0.97166
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8472 - accuracy: 0.6855 - val_loss: 0.9767 - val_accuracy: 0.6468
# Epoch 75/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8419 - accuracy: 0.6876
# Epoch 00075: val_loss did not improve from 0.97166
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8419 - accuracy: 0.6876 - val_loss: 0.9758 - val_accuracy: 0.6474
# Epoch 76/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.8452 - accuracy: 0.6884
# Epoch 00076: val_loss did not improve from 0.97166
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8451 - accuracy: 0.6883 - val_loss: 0.9745 - val_accuracy: 0.6480
# Epoch 77/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8458 - accuracy: 0.6850
# Epoch 00077: val_loss did not improve from 0.97166
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8458 - accuracy: 0.6850 - val_loss: 0.9765 - val_accuracy: 0.6471
# Epoch 78/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.8456 - accuracy: 0.6878
# Epoch 00078: val_loss did not improve from 0.97166
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8454 - accuracy: 0.6879 - val_loss: 0.9759 - val_accuracy: 0.6461
# Epoch 79/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8427 - accuracy: 0.6869
# Epoch 00079: val_loss did not improve from 0.97166
# 898/897 [==============================] - 31s 34ms/step - loss: 0.8427 - accuracy: 0.6869 - val_loss: 0.9743 - val_accuracy: 0.6473
# Epoch 80/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8468 - accuracy: 0.6858
# Epoch 00080: val_loss did not improve from 0.97166
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 898/897 [==============================] - 31s 34ms/step - loss: 0.8468 - accuracy: 0.6858 - val_loss: 0.9752 - val_accuracy: 0.6477
# Epoch 81/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8417 - accuracy: 0.6882
# Epoch 00081: val_loss did not improve from 0.97166
# 898/897 [==============================] - 31s 34ms/step - loss: 0.8417 - accuracy: 0.6882 - val_loss: 0.9747 - val_accuracy: 0.6480
# Epoch 82/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.8476 - accuracy: 0.6854
# Epoch 00082: val_loss did not improve from 0.97166
# 898/897 [==============================] - 30s 34ms/step - loss: 0.8479 - accuracy: 0.6853 - val_loss: 0.9751 - val_accuracy: 0.6473
# Epoch 83/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8426 - accuracy: 0.6880
# Epoch 00083: val_loss did not improve from 0.97166
# 898/897 [==============================] - 31s 34ms/step - loss: 0.8426 - accuracy: 0.6880 - val_loss: 0.9751 - val_accuracy: 0.6484
# Epoch 84/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8386 - accuracy: 0.6879
# Epoch 00084: val_loss did not improve from 0.97166
# 898/897 [==============================] - 31s 35ms/step - loss: 0.8386 - accuracy: 0.6879 - val_loss: 0.9754 - val_accuracy: 0.6471
# Epoch 85/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8416 - accuracy: 0.6868
# Epoch 00085: val_loss did not improve from 0.97166
# 898/897 [==============================] - 31s 35ms/step - loss: 0.8416 - accuracy: 0.6868 - val_loss: 0.9750 - val_accuracy: 0.6474
# Epoch 86/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.8401 - accuracy: 0.6879
# Epoch 00086: val_loss did not improve from 0.97166
# 898/897 [==============================] - 31s 35ms/step - loss: 0.8404 - accuracy: 0.6878 - val_loss: 0.9746 - val_accuracy: 0.6478
# Epoch 87/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8396 - accuracy: 0.6879
# Epoch 00087: val_loss did not improve from 0.97166
# 898/897 [==============================] - 31s 35ms/step - loss: 0.8396 - accuracy: 0.6879 - val_loss: 0.9762 - val_accuracy: 0.6470
# Epoch 88/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8412 - accuracy: 0.6906
# Epoch 00088: val_loss did not improve from 0.97166
# 898/897 [==============================] - 31s 35ms/step - loss: 0.8412 - accuracy: 0.6906 - val_loss: 0.9747 - val_accuracy: 0.6475
# Epoch 89/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.8437 - accuracy: 0.6843
# Epoch 00089: val_loss did not improve from 0.97166
# 898/897 [==============================] - 31s 35ms/step - loss: 0.8435 - accuracy: 0.6844 - val_loss: 0.9754 - val_accuracy: 0.6468
# Epoch 90/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8403 - accuracy: 0.6924
# Epoch 00090: val_loss did not improve from 0.97166
# 898/897 [==============================] - 31s 35ms/step - loss: 0.8403 - accuracy: 0.6924 - val_loss: 0.9766 - val_accuracy: 0.6475
# Epoch 91/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8391 - accuracy: 0.6922
# Epoch 00091: val_loss did not improve from 0.97166
# 898/897 [==============================] - 31s 35ms/step - loss: 0.8391 - accuracy: 0.6922 - val_loss: 0.9751 - val_accuracy: 0.6473
# Epoch 92/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8419 - accuracy: 0.6870
# Epoch 00092: val_loss did not improve from 0.97166
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 898/897 [==============================] - 31s 35ms/step - loss: 0.8419 - accuracy: 0.6870 - val_loss: 0.9769 - val_accuracy: 0.6473
# Epoch 93/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8399 - accuracy: 0.6874
# Epoch 00093: val_loss did not improve from 0.97166
# 898/897 [==============================] - 31s 35ms/step - loss: 0.8399 - accuracy: 0.6874 - val_loss: 0.9755 - val_accuracy: 0.6474
# Epoch 94/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.8437 - accuracy: 0.6876
# Epoch 00094: val_loss did not improve from 0.97166
# 898/897 [==============================] - 31s 35ms/step - loss: 0.8437 - accuracy: 0.6876 - val_loss: 0.9755 - val_accuracy: 0.6478
# Epoch 95/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8418 - accuracy: 0.6873
# Epoch 00095: val_loss did not improve from 0.97166
# 898/897 [==============================] - 31s 35ms/step - loss: 0.8418 - accuracy: 0.6873 - val_loss: 0.9751 - val_accuracy: 0.6477
# Epoch 96/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8459 - accuracy: 0.6848
# Epoch 00096: val_loss did not improve from 0.97166
# 898/897 [==============================] - 31s 35ms/step - loss: 0.8459 - accuracy: 0.6848 - val_loss: 0.9755 - val_accuracy: 0.6468
# Epoch 97/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.8375 - accuracy: 0.6882
# Epoch 00097: val_loss did not improve from 0.97166
# 898/897 [==============================] - 31s 35ms/step - loss: 0.8376 - accuracy: 0.6881 - val_loss: 0.9753 - val_accuracy: 0.6471
# Epoch 98/100
# 897/897 [============================>.] - ETA: 0s - loss: 0.8379 - accuracy: 0.6879
# Epoch 00098: val_loss did not improve from 0.97166
# 898/897 [==============================] - 31s 35ms/step - loss: 0.8380 - accuracy: 0.6880 - val_loss: 0.9757 - val_accuracy: 0.6477
# Epoch 99/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8446 - accuracy: 0.6824
# Epoch 00099: val_loss did not improve from 0.97166
# 898/897 [==============================] - 31s 35ms/step - loss: 0.8446 - accuracy: 0.6824 - val_loss: 0.9755 - val_accuracy: 0.6475
# Epoch 100/100
# 898/897 [==============================] - ETA: 0s - loss: 0.8447 - accuracy: 0.6877
# Epoch 00100: val_loss did not improve from 0.97166
# 898/897 [==============================] - 31s 34ms/step - loss: 0.8447 - accuracy: 0.6877 - val_loss: 0.9753 - val_accuracy: 0.6475

# %%
plt_path = base_path + 'plt.png'
#learning curve
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
#plt.show()

plt.savefig(plt_path)

# %%
import matplotlib.pyplot as plt

fig_path = base_path + 'fig_acc_loss.png'
def plot_model_performance(train_loss, train_acc, train_val_loss, train_val_acc):
    """ Plot model loss and accuracy through epochs. """
    blue= '#34495E'
    green = '#2ECC71'
    orange = '#E23B13'
    
    # Loss plot model (손실)
    fig, (ax1, ax2) = plt.subplots(2, figsize=(10, 8))
    ax1.plot(range(1, len(train_loss) + 1), train_loss, blue, linewidth=5, label='training')
    ax1.plot(range(1, len(train_val_loss) + 1), train_val_loss, green, linewidth=5, label='validation')
    ax1.set_xlabel('# epoch')
    ax1.set_ylabel('loss')
    ax1.tick_params('y')
    ax1.legend(loc='upper right', shadow=False)
    ax1.set_title('Model loss through #epochs', color=orange, fontweight='bold')
    
    # Accuracy plot model (정확도)
    ax2.plot(range(1, len(train_acc) + 1), train_acc, blue, linewidth=5, label='training')
    ax2.plot(range(1, len(train_val_acc) + 1), train_val_acc, green, linewidth=5, label='validation')
    ax2.set_xlabel('# epoch')
    ax2.set_ylabel('accuracy')
    ax2.tick_params('y')
    ax2.legend(loc='lower right', shadow=False)
    ax2.set_title('Model accuracy through #epochs', color=orange, fontweight='bold')
    fig.savefig(fig_path)

# %%
fig = plot_model_performance(
    train_loss=history.history.get('loss', []),
    train_acc=history.history.get('accuracy', []),
    train_val_loss=history.history.get('val_loss', []),
    train_val_acc=history.history.get('val_accuracy', [])
)

# %%
# CNN 구조 변경 시 모델 시각화 저장용
from tensorflow.keras.utils import plot_model
model_file_path = base_path + 'CNN.png'
plot_model(model, to_file=model_file_path, show_shapes=True, show_layer_names = True)
