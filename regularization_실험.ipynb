# %% [markdown]
# <a href="https://colab.research.google.com/github/seuch98/Data-Analysis-Term-Project/blob/main/regularization_%EC%8B%A4%ED%97%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

#dataset_path = 'fer2013.csv'
dataset_path = '/content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/참고 코드/challenges-in-representation-learning-facial-expression-recognition-challenge/fer2013/fer2013/fer2013.csv'
image_size=(48,48)

#csv 파일 읽어서 48*48 크기의 이미지에서 각 행의 픽셀 시퀀스 변환. 얼굴과 감정 레이블 반환

def load_fer2013():
    data = pd.read_csv(dataset_path)
    pixels = data['pixels'].tolist()
    width, height = 48, 48
    faces = []
    for pixel_sequence in pixels:
        face = [int(pixel) for pixel in pixel_sequence.split(' ')]
        face = np.asarray(face).reshape(width, height)
        face = cv2.resize(face.astype('uint8'),image_size)
        faces.append(face.astype('float32'))
    faces = np.asarray(faces)
    faces = np.expand_dims(faces, -1)
    emotions = pd.get_dummies(data['emotion']).values
    return faces, emotions

#이미지를 -1에서 1 사이의 크기로 조정하여 이미지를 전처리하는 표준 방법.
#이미지의 크기를 [0,1]로 255 나눠서 조정.
#0.5를 빼고 2를 곱하면 범위가 [-1,1]로 바뀜. 이건 컴퓨터 비전 문제에서 신경 네트워크 모델에 대한 더 나은 범위

def preprocess_input(x, v2=True):
    x = x.astype('float32') #######
    x = x / 255.0
    if v2:
        x = x - 0.5
        x = x * 2.0
    return x
 
faces, emotions = load_fer2013()
faces = preprocess_input(faces)
xtrain, xtest,ytrain,ytest = train_test_split(faces, emotions,test_size=0.2,shuffle=True, random_state = 1004)

# %% [markdown]
# **L1 regularization code**

# %%
from keras.callbacks import CSVLogger, ModelCheckpoint, EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from keras.layers import Activation, Convolution2D, Dropout, Conv2D
from keras.layers import AveragePooling2D, BatchNormalization
from keras.layers import GlobalAveragePooling2D
from keras.models import Sequential
from keras.layers import Flatten
from keras.models import Model
from keras.layers import Input
from keras.layers import MaxPooling2D
from keras.layers import SeparableConv2D
from keras import layers
from keras.regularizers import l1
import pandas as pd
import cv2
import numpy as np
 
# parameters
batch_size = 32
num_epochs = 50 #110
input_shape = (48, 48, 1)
verbose = 1
num_classes = 7
patience = 50
base_path = '/content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L1/6/'
#base_path = './models/'
l1_regularization=0.40 ###이 부분 값 바꿔가며 실험 진행
 
# data generator
data_generator = ImageDataGenerator(
                        featurewise_center=False,
                        featurewise_std_normalization=False,
                        rotation_range=10,
                        width_shift_range=0.1,
                        height_shift_range=0.1,
                        zoom_range=.1,
                        horizontal_flip=True)
 
# model parameters
regularization = l1(l1_regularization)
 
# base
img_input = Input(input_shape)
x = Conv2D(8, (3, 3), strides=(1, 1), kernel_regularizer=regularization, use_bias=False)(img_input)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Conv2D(8, (3, 3), strides=(1, 1), kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
 
# module 1
residual = Conv2D(16, (1, 1), strides=(2, 2), padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(16, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(16, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
 
# module 2
residual = Conv2D(32, (1, 1), strides=(2, 2), padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(32, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(32, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
 
# module 3
residual = Conv2D(64, (1, 1), strides=(2, 2),padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(64, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(64, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
 
# module 4
residual = Conv2D(128, (1, 1), strides=(2, 2),padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(128, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(128, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
x = Conv2D(num_classes, (3, 3), padding='same')(x)
x = GlobalAveragePooling2D()(x)
output = Activation('softmax',name='predictions')(x)
 
model = Model(img_input, output)
model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
 
# callbacks
log_file_path = base_path + '_emotion_training.log'
csv_logger = CSVLogger(log_file_path, append=False)
early_stop = EarlyStopping('val_loss', patience=patience)
reduce_lr = ReduceLROnPlateau('val_loss', factor=0.1, patience=int(patience/4), verbose=1)
trained_models_path = base_path + '_mini_XCEPTION'
model_names = trained_models_path + '.{epoch:02d}-{val_accuracy:.2f}.hdf5'
model_checkpoint = ModelCheckpoint(model_names, 'val_loss', verbose=1,save_best_only=True)
callbacks = [model_checkpoint, csv_logger, early_stop, reduce_lr]
 
history= model.fit_generator(data_generator.flow(xtrain, ytrain,batch_size),
                        steps_per_epoch=len(xtrain) / batch_size,
                        epochs=num_epochs, verbose=1, callbacks=callbacks,
                        validation_data=(xtest,ytest))
# Out:
# Model: "functional_23"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_12 (InputLayer)           [(None, 48, 48, 1)]  0
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 46, 46, 8)    72          input_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_154 (BatchN (None, 46, 46, 8)    32          conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 46, 46, 8)    0           batch_normalization_154[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 44, 44, 8)    576         activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_155 (BatchN (None, 44, 44, 8)    32          conv2d_78[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 44, 44, 8)    0           batch_normalization_155[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_88 (SeparableC (None, 44, 44, 16)   200         activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_157 (BatchN (None, 44, 44, 16)   64          separable_conv2d_88[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 44, 44, 16)   0           batch_normalization_157[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_89 (SeparableC (None, 44, 44, 16)   400         activation_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_158 (BatchN (None, 44, 44, 16)   64          separable_conv2d_89[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 22, 22, 16)   128         activation_67[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_44 (MaxPooling2D) (None, 22, 22, 16)   0           batch_normalization_158[0][0]
# __________________________________________________________________________________________________
# batch_normalization_156 (BatchN (None, 22, 22, 16)   64          conv2d_79[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 22, 22, 16)   0           max_pooling2d_44[0][0]
#                                                                  batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_90 (SeparableC (None, 22, 22, 32)   656         add_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_160 (BatchN (None, 22, 22, 32)   128         separable_conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 22, 22, 32)   0           batch_normalization_160[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_91 (SeparableC (None, 22, 22, 32)   1312        activation_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_161 (BatchN (None, 22, 22, 32)   128         separable_conv2d_91[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 11, 11, 32)   512         add_44[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_45 (MaxPooling2D) (None, 11, 11, 32)   0           batch_normalization_161[0][0]
# __________________________________________________________________________________________________
# batch_normalization_159 (BatchN (None, 11, 11, 32)   128         conv2d_80[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 11, 11, 32)   0           max_pooling2d_45[0][0]
#                                                                  batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_92 (SeparableC (None, 11, 11, 64)   2336        add_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_163 (BatchN (None, 11, 11, 64)   256         separable_conv2d_92[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 11, 11, 64)   0           batch_normalization_163[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_93 (SeparableC (None, 11, 11, 64)   4672        activation_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_164 (BatchN (None, 11, 11, 64)   256         separable_conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 6, 6, 64)     2048        add_45[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_46 (MaxPooling2D) (None, 6, 6, 64)     0           batch_normalization_164[0][0]
# __________________________________________________________________________________________________
# batch_normalization_162 (BatchN (None, 6, 6, 64)     256         conv2d_81[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 6, 6, 64)     0           max_pooling2d_46[0][0]
#                                                                  batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_94 (SeparableC (None, 6, 6, 128)    8768        add_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_166 (BatchN (None, 6, 6, 128)    512         separable_conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 6, 6, 128)    0           batch_normalization_166[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_95 (SeparableC (None, 6, 6, 128)    17536       activation_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_167 (BatchN (None, 6, 6, 128)    512         separable_conv2d_95[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 3, 3, 128)    8192        add_46[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_47 (MaxPooling2D) (None, 3, 3, 128)    0           batch_normalization_167[0][0]
# __________________________________________________________________________________________________
# batch_normalization_165 (BatchN (None, 3, 3, 128)    512         conv2d_82[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 3, 3, 128)    0           max_pooling2d_47[0][0]
#                                                                  batch_normalization_165[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 3, 3, 7)      8071        add_47[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_11 (Gl (None, 7)            0           conv2d_83[0][0]
# __________________________________________________________________________________________________
# predictions (Activation)        (None, 7)            0           global_average_pooling2d_11[0][0]
# ==================================================================================================
# Total params: 58,423
# Trainable params: 56,951
# Non-trainable params: 1,472
# __________________________________________________________________________________________________
# Epoch 1/50
# 898/897 [==============================] - ETA: 0s - loss: 4.2821 - accuracy: 0.2965
# Epoch 00001: val_loss improved from inf to 1.83024, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L1/6/_mini_XCEPTION.01-0.33.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 4.2821 - accuracy: 0.2965 - val_loss: 1.8302 - val_accuracy: 0.3348
# Epoch 2/50
# 896/897 [============================>.] - ETA: 0s - loss: 1.6223 - accuracy: 0.4027
# Epoch 00002: val_loss improved from 1.83024 to 1.59600, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L1/6/_mini_XCEPTION.02-0.42.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 1.6219 - accuracy: 0.4028 - val_loss: 1.5960 - val_accuracy: 0.4167
# Epoch 3/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.5041 - accuracy: 0.4524
# Epoch 00003: val_loss improved from 1.59600 to 1.39998, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L1/6/_mini_XCEPTION.03-0.50.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 1.5038 - accuracy: 0.4525 - val_loss: 1.4000 - val_accuracy: 0.5001
# Epoch 4/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.4267 - accuracy: 0.4818
# Epoch 00004: val_loss did not improve from 1.39998
# 898/897 [==============================] - 18s 20ms/step - loss: 1.4268 - accuracy: 0.4818 - val_loss: 1.5935 - val_accuracy: 0.4252
# Epoch 5/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.3615 - accuracy: 0.5069
# Epoch 00005: val_loss did not improve from 1.39998
# 898/897 [==============================] - 19s 21ms/step - loss: 1.3613 - accuracy: 0.5069 - val_loss: 1.7383 - val_accuracy: 0.3727
# Epoch 6/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.3167 - accuracy: 0.5228
# Epoch 00006: val_loss improved from 1.39998 to 1.34848, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L1/6/_mini_XCEPTION.06-0.51.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 1.3167 - accuracy: 0.5228 - val_loss: 1.3485 - val_accuracy: 0.5146
# Epoch 7/50
# 898/897 [==============================] - ETA: 0s - loss: 1.2902 - accuracy: 0.5320
# Epoch 00007: val_loss improved from 1.34848 to 1.30024, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L1/6/_mini_XCEPTION.07-0.54.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 1.2902 - accuracy: 0.5320 - val_loss: 1.3002 - val_accuracy: 0.5383
# Epoch 8/50
# 898/897 [==============================] - ETA: 0s - loss: 1.2656 - accuracy: 0.5420
# Epoch 00008: val_loss improved from 1.30024 to 1.25671, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L1/6/_mini_XCEPTION.08-0.56.hdf5
# 898/897 [==============================] - 18s 21ms/step - loss: 1.2656 - accuracy: 0.5420 - val_loss: 1.2567 - val_accuracy: 0.5612
# Epoch 9/50
# 896/897 [============================>.] - ETA: 0s - loss: 1.2491 - accuracy: 0.5543
# Epoch 00009: val_loss improved from 1.25671 to 1.21813, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L1/6/_mini_XCEPTION.09-0.56.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 1.2489 - accuracy: 0.5544 - val_loss: 1.2181 - val_accuracy: 0.5621
# Epoch 10/50
# 898/897 [==============================] - ETA: 0s - loss: 1.2350 - accuracy: 0.5550
# Epoch 00010: val_loss did not improve from 1.21813
# 898/897 [==============================] - 19s 21ms/step - loss: 1.2350 - accuracy: 0.5550 - val_loss: 1.2963 - val_accuracy: 0.5587
# Epoch 11/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.2225 - accuracy: 0.5613
# Epoch 00011: val_loss did not improve from 1.21813
# 898/897 [==============================] - 19s 21ms/step - loss: 1.2223 - accuracy: 0.5614 - val_loss: 1.2812 - val_accuracy: 0.5430
# Epoch 12/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.2090 - accuracy: 0.5661
# Epoch 00012: val_loss improved from 1.21813 to 1.20950, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L1/6/_mini_XCEPTION.12-0.56.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 1.2090 - accuracy: 0.5661 - val_loss: 1.2095 - val_accuracy: 0.5575
# Epoch 13/50
# 896/897 [============================>.] - ETA: 0s - loss: 1.1967 - accuracy: 0.5706
# Epoch 00013: val_loss did not improve from 1.20950
# 898/897 [==============================] - 18s 21ms/step - loss: 1.1963 - accuracy: 0.5707 - val_loss: 1.2772 - val_accuracy: 0.5412
# Epoch 14/50
# 898/897 [==============================] - ETA: 0s - loss: 1.1793 - accuracy: 0.5773
# Epoch 00014: val_loss improved from 1.20950 to 1.17065, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L1/6/_mini_XCEPTION.14-0.58.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 1.1793 - accuracy: 0.5773 - val_loss: 1.1707 - val_accuracy: 0.5798
# Epoch 15/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.1722 - accuracy: 0.5817
# Epoch 00015: val_loss did not improve from 1.17065
# 898/897 [==============================] - 18s 21ms/step - loss: 1.1726 - accuracy: 0.5814 - val_loss: 1.1806 - val_accuracy: 0.5844
# Epoch 16/50
# 896/897 [============================>.] - ETA: 0s - loss: 1.1671 - accuracy: 0.5774
# Epoch 00016: val_loss did not improve from 1.17065
# 898/897 [==============================] - 19s 21ms/step - loss: 1.1671 - accuracy: 0.5773 - val_loss: 1.2310 - val_accuracy: 0.5596
# Epoch 17/50
# 898/897 [==============================] - ETA: 0s - loss: 1.1533 - accuracy: 0.5869
# Epoch 00017: val_loss improved from 1.17065 to 1.16398, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L1/6/_mini_XCEPTION.17-0.58.hdf5
# 898/897 [==============================] - 18s 21ms/step - loss: 1.1533 - accuracy: 0.5869 - val_loss: 1.1640 - val_accuracy: 0.5791
# Epoch 18/50
# 898/897 [==============================] - ETA: 0s - loss: 1.1520 - accuracy: 0.5888
# Epoch 00018: val_loss did not improve from 1.16398
# 898/897 [==============================] - 18s 21ms/step - loss: 1.1520 - accuracy: 0.5888 - val_loss: 1.1924 - val_accuracy: 0.5761
# Epoch 19/50
# 898/897 [==============================] - ETA: 0s - loss: 1.1372 - accuracy: 0.5934
# Epoch 00019: val_loss improved from 1.16398 to 1.12306, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L1/6/_mini_XCEPTION.19-0.59.hdf5
# 898/897 [==============================] - 18s 21ms/step - loss: 1.1372 - accuracy: 0.5934 - val_loss: 1.1231 - val_accuracy: 0.5899
# Epoch 20/50
# 896/897 [============================>.] - ETA: 0s - loss: 1.1369 - accuracy: 0.5945
# Epoch 00020: val_loss did not improve from 1.12306
# 898/897 [==============================] - 18s 20ms/step - loss: 1.1362 - accuracy: 0.5947 - val_loss: 1.1858 - val_accuracy: 0.5711
# Epoch 21/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.1228 - accuracy: 0.5969
# Epoch 00021: val_loss did not improve from 1.12306
# 898/897 [==============================] - 18s 20ms/step - loss: 1.1229 - accuracy: 0.5968 - val_loss: 1.2242 - val_accuracy: 0.5695
# Epoch 22/50
# 898/897 [==============================] - ETA: 0s - loss: 1.1198 - accuracy: 0.5982
# Epoch 00022: val_loss did not improve from 1.12306
# 898/897 [==============================] - 18s 21ms/step - loss: 1.1198 - accuracy: 0.5982 - val_loss: 1.2916 - val_accuracy: 0.5591
# Epoch 23/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.1170 - accuracy: 0.6006
# Epoch 00023: val_loss did not improve from 1.12306
# 898/897 [==============================] - 19s 21ms/step - loss: 1.1172 - accuracy: 0.6006 - val_loss: 1.1621 - val_accuracy: 0.5887
# Epoch 24/50
# 896/897 [============================>.] - ETA: 0s - loss: 1.1062 - accuracy: 0.6063
# Epoch 00024: val_loss did not improve from 1.12306
# 898/897 [==============================] - 19s 21ms/step - loss: 1.1066 - accuracy: 0.6061 - val_loss: 1.1411 - val_accuracy: 0.5924
# Epoch 25/50
# 898/897 [==============================] - ETA: 0s - loss: 1.1036 - accuracy: 0.6083
# Epoch 00025: val_loss did not improve from 1.12306
# 898/897 [==============================] - 19s 21ms/step - loss: 1.1036 - accuracy: 0.6083 - val_loss: 1.1671 - val_accuracy: 0.5772
# Epoch 26/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.0975 - accuracy: 0.6102
# Epoch 00026: val_loss did not improve from 1.12306
# 898/897 [==============================] - 18s 21ms/step - loss: 1.0977 - accuracy: 0.6102 - val_loss: 1.3522 - val_accuracy: 0.5330
# Epoch 27/50
# 898/897 [==============================] - ETA: 0s - loss: 1.0983 - accuracy: 0.6088
# Epoch 00027: val_loss did not improve from 1.12306
# 898/897 [==============================] - 18s 21ms/step - loss: 1.0983 - accuracy: 0.6088 - val_loss: 1.1967 - val_accuracy: 0.5731
# Epoch 28/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.0969 - accuracy: 0.6108
# Epoch 00028: val_loss did not improve from 1.12306
# 898/897 [==============================] - 18s 20ms/step - loss: 1.0967 - accuracy: 0.6109 - val_loss: 1.1412 - val_accuracy: 0.6000
# Epoch 29/50
# 896/897 [============================>.] - ETA: 0s - loss: 1.0894 - accuracy: 0.6115
# Epoch 00029: val_loss did not improve from 1.12306
# 898/897 [==============================] - 19s 21ms/step - loss: 1.0895 - accuracy: 0.6117 - val_loss: 1.2477 - val_accuracy: 0.5614
# Epoch 30/50
# 896/897 [============================>.] - ETA: 0s - loss: 1.0850 - accuracy: 0.6121
# Epoch 00030: val_loss did not improve from 1.12306
# 898/897 [==============================] - 18s 20ms/step - loss: 1.0848 - accuracy: 0.6121 - val_loss: 1.1659 - val_accuracy: 0.5825
# Epoch 31/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.0731 - accuracy: 0.6186
# Epoch 00031: val_loss did not improve from 1.12306
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 898/897 [==============================] - 19s 21ms/step - loss: 1.0733 - accuracy: 0.6186 - val_loss: 1.2307 - val_accuracy: 0.5638
# Epoch 32/50
# 898/897 [==============================] - ETA: 0s - loss: 0.9899 - accuracy: 0.6397
# Epoch 00032: val_loss improved from 1.12306 to 1.02956, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L1/6/_mini_XCEPTION.32-0.62.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 0.9899 - accuracy: 0.6397 - val_loss: 1.0296 - val_accuracy: 0.6172
# Epoch 33/50
# 898/897 [==============================] - ETA: 0s - loss: 0.9764 - accuracy: 0.6426
# Epoch 00033: val_loss did not improve from 1.02956
# 898/897 [==============================] - 19s 21ms/step - loss: 0.9764 - accuracy: 0.6426 - val_loss: 1.0375 - val_accuracy: 0.6155
# Epoch 34/50
# 898/897 [==============================] - ETA: 0s - loss: 0.9653 - accuracy: 0.6453
# Epoch 00034: val_loss did not improve from 1.02956
# 898/897 [==============================] - 18s 21ms/step - loss: 0.9653 - accuracy: 0.6453 - val_loss: 1.0323 - val_accuracy: 0.6215
# Epoch 35/50
# 897/897 [============================>.] - ETA: 0s - loss: 0.9645 - accuracy: 0.6470
# Epoch 00035: val_loss improved from 1.02956 to 1.02287, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L1/6/_mini_XCEPTION.35-0.62.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 0.9644 - accuracy: 0.6470 - val_loss: 1.0229 - val_accuracy: 0.6213
# Epoch 36/50
# 898/897 [==============================] - ETA: 0s - loss: 0.9587 - accuracy: 0.6461
# Epoch 00036: val_loss improved from 1.02287 to 1.01459, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L1/6/_mini_XCEPTION.36-0.63.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 0.9587 - accuracy: 0.6461 - val_loss: 1.0146 - val_accuracy: 0.6258
# Epoch 37/50
# 896/897 [============================>.] - ETA: 0s - loss: 0.9576 - accuracy: 0.6485
# Epoch 00037: val_loss did not improve from 1.01459
# 898/897 [==============================] - 18s 20ms/step - loss: 0.9575 - accuracy: 0.6485 - val_loss: 1.0176 - val_accuracy: 0.6275
# Epoch 38/50
# 896/897 [============================>.] - ETA: 0s - loss: 0.9564 - accuracy: 0.6468
# Epoch 00038: val_loss did not improve from 1.01459
# 898/897 [==============================] - 18s 20ms/step - loss: 0.9562 - accuracy: 0.6470 - val_loss: 1.0172 - val_accuracy: 0.6278
# Epoch 39/50
# 896/897 [============================>.] - ETA: 0s - loss: 0.9590 - accuracy: 0.6497
# Epoch 00039: val_loss improved from 1.01459 to 0.99920, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L1/6/_mini_XCEPTION.39-0.63.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 0.9591 - accuracy: 0.6496 - val_loss: 0.9992 - val_accuracy: 0.6275
# Epoch 40/50
# 896/897 [============================>.] - ETA: 0s - loss: 0.9442 - accuracy: 0.6536
# Epoch 00040: val_loss did not improve from 0.99920
# 898/897 [==============================] - 19s 21ms/step - loss: 0.9445 - accuracy: 0.6536 - val_loss: 1.0051 - val_accuracy: 0.6300
# Epoch 41/50
# 898/897 [==============================] - ETA: 0s - loss: 0.9465 - accuracy: 0.6540
# Epoch 00041: val_loss did not improve from 0.99920
# 898/897 [==============================] - 19s 21ms/step - loss: 0.9465 - accuracy: 0.6540 - val_loss: 1.0271 - val_accuracy: 0.6170
# Epoch 42/50
# 896/897 [============================>.] - ETA: 0s - loss: 0.9472 - accuracy: 0.6537
# Epoch 00042: val_loss did not improve from 0.99920
# 898/897 [==============================] - 18s 20ms/step - loss: 0.9473 - accuracy: 0.6536 - val_loss: 1.0219 - val_accuracy: 0.6230
# Epoch 43/50
# 897/897 [============================>.] - ETA: 0s - loss: 0.9469 - accuracy: 0.6510
# Epoch 00043: val_loss did not improve from 0.99920
# 898/897 [==============================] - 18s 20ms/step - loss: 0.9472 - accuracy: 0.6509 - val_loss: 1.0412 - val_accuracy: 0.6151
# Epoch 44/50
# 898/897 [==============================] - ETA: 0s - loss: 0.9442 - accuracy: 0.6566
# Epoch 00044: val_loss did not improve from 0.99920
# 898/897 [==============================] - 18s 20ms/step - loss: 0.9442 - accuracy: 0.6566 - val_loss: 1.0134 - val_accuracy: 0.6286
# Epoch 45/50
# 897/897 [============================>.] - ETA: 0s - loss: 0.9429 - accuracy: 0.6508
# Epoch 00045: val_loss did not improve from 0.99920
# 898/897 [==============================] - 18s 20ms/step - loss: 0.9431 - accuracy: 0.6508 - val_loss: 1.0100 - val_accuracy: 0.6280
# Epoch 46/50
# 898/897 [==============================] - ETA: 0s - loss: 0.9371 - accuracy: 0.6541
# Epoch 00046: val_loss did not improve from 0.99920
# 898/897 [==============================] - 18s 21ms/step - loss: 0.9371 - accuracy: 0.6541 - val_loss: 1.0172 - val_accuracy: 0.6317
# Epoch 47/50
# 898/897 [==============================] - ETA: 0s - loss: 0.9363 - accuracy: 0.6549
# Epoch 00047: val_loss did not improve from 0.99920
# 898/897 [==============================] - 18s 20ms/step - loss: 0.9363 - accuracy: 0.6549 - val_loss: 1.0190 - val_accuracy: 0.6262
# Epoch 48/50
# 896/897 [============================>.] - ETA: 0s - loss: 0.9333 - accuracy: 0.6574
# Epoch 00048: val_loss did not improve from 0.99920
# 898/897 [==============================] - 18s 20ms/step - loss: 0.9332 - accuracy: 0.6576 - val_loss: 1.0100 - val_accuracy: 0.6239
# Epoch 49/50
# 898/897 [==============================] - ETA: 0s - loss: 0.9355 - accuracy: 0.6534
# Epoch 00049: val_loss did not improve from 0.99920
# 898/897 [==============================] - 18s 21ms/step - loss: 0.9355 - accuracy: 0.6534 - val_loss: 1.0019 - val_accuracy: 0.6336
# Epoch 50/50
# 896/897 [============================>.] - ETA: 0s - loss: 0.9333 - accuracy: 0.6550
# Epoch 00050: val_loss did not improve from 0.99920
# 898/897 [==============================] - 18s 21ms/step - loss: 0.9331 - accuracy: 0.6550 - val_loss: 1.0314 - val_accuracy: 0.6163

# %%
plt_path = base_path + 'plt.png'
#learning curve
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
#plt.show()

plt.savefig(plt_path)

# %%
import matplotlib.pyplot as plt

fig_path = base_path + 'fig_acc_loss.png'
def plot_model_performance(train_loss, train_acc, train_val_loss, train_val_acc):
    """ Plot model loss and accuracy through epochs. """
    blue= '#34495E'
    green = '#2ECC71'
    orange = '#E23B13'
    
    # Loss plot model (손실)
    fig, (ax1, ax2) = plt.subplots(2, figsize=(10, 8))
    ax1.plot(range(1, len(train_loss) + 1), train_loss, blue, linewidth=5, label='training')
    ax1.plot(range(1, len(train_val_loss) + 1), train_val_loss, green, linewidth=5, label='validation')
    ax1.set_xlabel('# epoch')
    ax1.set_ylabel('loss')
    ax1.tick_params('y')
    ax1.legend(loc='upper right', shadow=False)
    ax1.set_title('Model loss through #epochs', color=orange, fontweight='bold')
    
    # Accuracy plot model (정확도)
    ax2.plot(range(1, len(train_acc) + 1), train_acc, blue, linewidth=5, label='training')
    ax2.plot(range(1, len(train_val_acc) + 1), train_val_acc, green, linewidth=5, label='validation')
    ax2.set_xlabel('# epoch')
    ax2.set_ylabel('accuracy')
    ax2.tick_params('y')
    ax2.legend(loc='lower right', shadow=False)
    ax2.set_title('Model accuracy through #epochs', color=orange, fontweight='bold')
    fig.savefig(fig_path)

# %%
fig = plot_model_performance(
    train_loss=history.history.get('loss', []),
    train_acc=history.history.get('accuracy', []),
    train_val_loss=history.history.get('val_loss', []),
    train_val_acc=history.history.get('val_accuracy', [])
)

# %% [markdown]
# **L1_L2 Regularization**

# %%
from keras.callbacks import CSVLogger, ModelCheckpoint, EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from keras.layers import Activation, Convolution2D, Dropout, Conv2D
from keras.layers import AveragePooling2D, BatchNormalization
from keras.layers import GlobalAveragePooling2D
from keras.models import Sequential
from keras.layers import Flatten
from keras.models import Model
from keras.layers import Input
from keras.layers import MaxPooling2D
from keras.layers import SeparableConv2D
from keras import layers
from keras.regularizers import l1_l2
import pandas as pd
import cv2
import numpy as np
 
# parameters
batch_size = 32
num_epochs = 50 #110
input_shape = (48, 48, 1)
verbose = 1
num_classes = 7
patience = 50
base_path = '/content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L1_L2/6/'
#base_path = './models/'
 
# data generator
data_generator = ImageDataGenerator(
                        featurewise_center=False,
                        featurewise_std_normalization=False,
                        rotation_range=10,
                        width_shift_range=0.1,
                        height_shift_range=0.1,
                        zoom_range=.1,
                        horizontal_flip=True)
 
# model parameters
regularization = l1_l2(l1= 0.40, l2 = 0.40) ###이 부분 값 바꿔가며 실험 진행
 
# base
img_input = Input(input_shape)
x = Conv2D(8, (3, 3), strides=(1, 1), kernel_regularizer=regularization, use_bias=False)(img_input)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Conv2D(8, (3, 3), strides=(1, 1), kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
 
# module 1
residual = Conv2D(16, (1, 1), strides=(2, 2), padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(16, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(16, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
 
# module 2
residual = Conv2D(32, (1, 1), strides=(2, 2), padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(32, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(32, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
 
# module 3
residual = Conv2D(64, (1, 1), strides=(2, 2),padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(64, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(64, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
 
# module 4
residual = Conv2D(128, (1, 1), strides=(2, 2),padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(128, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(128, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
x = Conv2D(num_classes, (3, 3), padding='same')(x)
x = GlobalAveragePooling2D()(x)
output = Activation('softmax',name='predictions')(x)
 
model = Model(img_input, output)
model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
 
# callbacks
log_file_path = base_path + '_emotion_training.log'
csv_logger = CSVLogger(log_file_path, append=False)
early_stop = EarlyStopping('val_loss', patience=patience)
reduce_lr = ReduceLROnPlateau('val_loss', factor=0.1, patience=int(patience/4), verbose=1)
trained_models_path = base_path + '_mini_XCEPTION'
model_names = trained_models_path + '.{epoch:02d}-{val_accuracy:.2f}.hdf5'
model_checkpoint = ModelCheckpoint(model_names, 'val_loss', verbose=1,save_best_only=True)
callbacks = [model_checkpoint, csv_logger, early_stop, reduce_lr]
 
history= model.fit_generator(data_generator.flow(xtrain, ytrain,batch_size),
                        steps_per_epoch=len(xtrain) / batch_size,
                        epochs=num_epochs, verbose=1, callbacks=callbacks,
                        validation_data=(xtest,ytest))
# Out:
# Model: "functional_25"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_13 (InputLayer)           [(None, 48, 48, 1)]  0
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 46, 46, 8)    72          input_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_168 (BatchN (None, 46, 46, 8)    32          conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 46, 46, 8)    0           batch_normalization_168[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 44, 44, 8)    576         activation_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_169 (BatchN (None, 44, 44, 8)    32          conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 44, 44, 8)    0           batch_normalization_169[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_96 (SeparableC (None, 44, 44, 16)   200         activation_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_171 (BatchN (None, 44, 44, 16)   64          separable_conv2d_96[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 44, 44, 16)   0           batch_normalization_171[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_97 (SeparableC (None, 44, 44, 16)   400         activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_172 (BatchN (None, 44, 44, 16)   64          separable_conv2d_97[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 22, 22, 16)   128         activation_73[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_48 (MaxPooling2D) (None, 22, 22, 16)   0           batch_normalization_172[0][0]
# __________________________________________________________________________________________________
# batch_normalization_170 (BatchN (None, 22, 22, 16)   64          conv2d_86[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 22, 22, 16)   0           max_pooling2d_48[0][0]
#                                                                  batch_normalization_170[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_98 (SeparableC (None, 22, 22, 32)   656         add_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_174 (BatchN (None, 22, 22, 32)   128         separable_conv2d_98[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 22, 22, 32)   0           batch_normalization_174[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_99 (SeparableC (None, 22, 22, 32)   1312        activation_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_175 (BatchN (None, 22, 22, 32)   128         separable_conv2d_99[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 11, 11, 32)   512         add_48[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_49 (MaxPooling2D) (None, 11, 11, 32)   0           batch_normalization_175[0][0]
# __________________________________________________________________________________________________
# batch_normalization_173 (BatchN (None, 11, 11, 32)   128         conv2d_87[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, 11, 11, 32)   0           max_pooling2d_49[0][0]
#                                                                  batch_normalization_173[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_100 (Separable (None, 11, 11, 64)   2336        add_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_177 (BatchN (None, 11, 11, 64)   256         separable_conv2d_100[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 11, 11, 64)   0           batch_normalization_177[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_101 (Separable (None, 11, 11, 64)   4672        activation_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_178 (BatchN (None, 11, 11, 64)   256         separable_conv2d_101[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 6, 6, 64)     2048        add_49[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_50 (MaxPooling2D) (None, 6, 6, 64)     0           batch_normalization_178[0][0]
# __________________________________________________________________________________________________
# batch_normalization_176 (BatchN (None, 6, 6, 64)     256         conv2d_88[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, 6, 6, 64)     0           max_pooling2d_50[0][0]
#                                                                  batch_normalization_176[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_102 (Separable (None, 6, 6, 128)    8768        add_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_180 (BatchN (None, 6, 6, 128)    512         separable_conv2d_102[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 6, 6, 128)    0           batch_normalization_180[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_103 (Separable (None, 6, 6, 128)    17536       activation_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_181 (BatchN (None, 6, 6, 128)    512         separable_conv2d_103[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 3, 3, 128)    8192        add_50[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_51 (MaxPooling2D) (None, 3, 3, 128)    0           batch_normalization_181[0][0]
# __________________________________________________________________________________________________
# batch_normalization_179 (BatchN (None, 3, 3, 128)    512         conv2d_89[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, 3, 3, 128)    0           max_pooling2d_51[0][0]
#                                                                  batch_normalization_179[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 3, 3, 7)      8071        add_51[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_12 (Gl (None, 7)            0           conv2d_90[0][0]
# __________________________________________________________________________________________________
# predictions (Activation)        (None, 7)            0           global_average_pooling2d_12[0][0]
# ==================================================================================================
# Total params: 58,423
# Trainable params: 56,951
# Non-trainable params: 1,472
# __________________________________________________________________________________________________
# Epoch 1/50
# 615/897 [===================>..........] - ETA: 5s - loss: 1.7987 - accuracy: 0.3223
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-24311871ded6> in <module>()
#     115                         steps_per_epoch=len(xtrain) / batch_size,
#     116                         epochs=num_epochs, verbose=1, callbacks=callbacks,
# --> 117                         validation_data=(xtest,ytest))
#     118
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1827         use_multiprocessing=use_multiprocessing,
#    1828         shuffle=shuffle,
# -> 1829         initial_epoch=initial_epoch)
#    1830
#    1831   @deprecation.deprecated(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
plt_path = base_path + 'plt.png'
#learning curve
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
#plt.show()

plt.savefig(plt_path)

# %%
import matplotlib.pyplot as plt

fig_path = base_path + 'fig_acc_loss.png'
def plot_model_performance(train_loss, train_acc, train_val_loss, train_val_acc):
    """ Plot model loss and accuracy through epochs. """
    blue= '#34495E'
    green = '#2ECC71'
    orange = '#E23B13'
    
    # Loss plot model (손실)
    fig, (ax1, ax2) = plt.subplots(2, figsize=(10, 8))
    ax1.plot(range(1, len(train_loss) + 1), train_loss, blue, linewidth=5, label='training')
    ax1.plot(range(1, len(train_val_loss) + 1), train_val_loss, green, linewidth=5, label='validation')
    ax1.set_xlabel('# epoch')
    ax1.set_ylabel('loss')
    ax1.tick_params('y')
    ax1.legend(loc='upper right', shadow=False)
    ax1.set_title('Model loss through #epochs', color=orange, fontweight='bold')
    
    # Accuracy plot model (정확도)
    ax2.plot(range(1, len(train_acc) + 1), train_acc, blue, linewidth=5, label='training')
    ax2.plot(range(1, len(train_val_acc) + 1), train_val_acc, green, linewidth=5, label='validation')
    ax2.set_xlabel('# epoch')
    ax2.set_ylabel('accuracy')
    ax2.tick_params('y')
    ax2.legend(loc='lower right', shadow=False)
    ax2.set_title('Model accuracy through #epochs', color=orange, fontweight='bold')
    fig.savefig(fig_path)

# %%
fig = plot_model_performance(
    train_loss=history.history.get('loss', []),
    train_acc=history.history.get('accuracy', []),
    train_val_loss=history.history.get('val_loss', []),
    train_val_acc=history.history.get('val_accuracy', [])
)

# %% [markdown]
# **L2 regularization**

# %%
from keras.callbacks import CSVLogger, ModelCheckpoint, EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from keras.layers import Activation, Convolution2D, Dropout, Conv2D
from keras.layers import AveragePooling2D, BatchNormalization
from keras.layers import GlobalAveragePooling2D
from keras.models import Sequential
from keras.layers import Flatten
from keras.models import Model
from keras.layers import Input
from keras.layers import MaxPooling2D
from keras.layers import SeparableConv2D
from keras import layers
from keras.regularizers import l2
import pandas as pd
import cv2
import numpy as np
 
# parameters
batch_size = 32
num_epochs = 50 #110
input_shape = (48, 48, 1)
verbose = 1
num_classes = 7
patience = 50
base_path = '/content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L2/3/'
#base_path = './models/'
l2_regularization=0.16 ###이 부분 값 바꿔가며 실험 진행
 
# data generator
data_generator = ImageDataGenerator(
                        featurewise_center=False,
                        featurewise_std_normalization=False,
                        rotation_range=10,
                        width_shift_range=0.1,
                        height_shift_range=0.1,
                        zoom_range=.1,
                        horizontal_flip=True)
 
# model parameters
regularization = l2(l2_regularization)
 
# base
img_input = Input(input_shape)
x = Conv2D(8, (3, 3), strides=(1, 1), kernel_regularizer=regularization, use_bias=False)(img_input)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Conv2D(8, (3, 3), strides=(1, 1), kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
 
# module 1
residual = Conv2D(16, (1, 1), strides=(2, 2), padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(16, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(16, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
 
# module 2
residual = Conv2D(32, (1, 1), strides=(2, 2), padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(32, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(32, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
 
# module 3
residual = Conv2D(64, (1, 1), strides=(2, 2),padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(64, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(64, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
 
# module 4
residual = Conv2D(128, (1, 1), strides=(2, 2),padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(128, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(128, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
x = Conv2D(num_classes, (3, 3), padding='same')(x)
x = GlobalAveragePooling2D()(x)
output = Activation('softmax',name='predictions')(x)
 
model = Model(img_input, output)
model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
 
# callbacks
log_file_path = base_path + '_emotion_training.log'
csv_logger = CSVLogger(log_file_path, append=False)
early_stop = EarlyStopping('val_loss', patience=patience)
reduce_lr = ReduceLROnPlateau('val_loss', factor=0.1, patience=int(patience/4), verbose=1)
trained_models_path = base_path + '_mini_XCEPTION'
model_names = trained_models_path + '.{epoch:02d}-{val_accuracy:.2f}.hdf5'
model_checkpoint = ModelCheckpoint(model_names, 'val_loss', verbose=1,save_best_only=True)
callbacks = [model_checkpoint, csv_logger, early_stop, reduce_lr]
 
history= model.fit_generator(data_generator.flow(xtrain, ytrain,batch_size),
                        steps_per_epoch=len(xtrain) / batch_size,
                        epochs=num_epochs, verbose=1, callbacks=callbacks,
                        validation_data=(xtest,ytest))
# Out:
# Model: "functional_31"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_16 (InputLayer)           [(None, 48, 48, 1)]  0
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 46, 46, 8)    72          input_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_210 (BatchN (None, 46, 46, 8)    32          conv2d_105[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 46, 46, 8)    0           batch_normalization_210[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 44, 44, 8)    576         activation_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_211 (BatchN (None, 44, 44, 8)    32          conv2d_106[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 44, 44, 8)    0           batch_normalization_211[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_120 (Separable (None, 44, 44, 16)   200         activation_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_213 (BatchN (None, 44, 44, 16)   64          separable_conv2d_120[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 44, 44, 16)   0           batch_normalization_213[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_121 (Separable (None, 44, 44, 16)   400         activation_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_214 (BatchN (None, 44, 44, 16)   64          separable_conv2d_121[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 22, 22, 16)   128         activation_91[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_60 (MaxPooling2D) (None, 22, 22, 16)   0           batch_normalization_214[0][0]
# __________________________________________________________________________________________________
# batch_normalization_212 (BatchN (None, 22, 22, 16)   64          conv2d_107[0][0]
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, 22, 22, 16)   0           max_pooling2d_60[0][0]
#                                                                  batch_normalization_212[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_122 (Separable (None, 22, 22, 32)   656         add_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_216 (BatchN (None, 22, 22, 32)   128         separable_conv2d_122[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 22, 22, 32)   0           batch_normalization_216[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_123 (Separable (None, 22, 22, 32)   1312        activation_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_217 (BatchN (None, 22, 22, 32)   128         separable_conv2d_123[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 11, 11, 32)   512         add_60[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_61 (MaxPooling2D) (None, 11, 11, 32)   0           batch_normalization_217[0][0]
# __________________________________________________________________________________________________
# batch_normalization_215 (BatchN (None, 11, 11, 32)   128         conv2d_108[0][0]
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, 11, 11, 32)   0           max_pooling2d_61[0][0]
#                                                                  batch_normalization_215[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_124 (Separable (None, 11, 11, 64)   2336        add_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_219 (BatchN (None, 11, 11, 64)   256         separable_conv2d_124[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 11, 11, 64)   0           batch_normalization_219[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_125 (Separable (None, 11, 11, 64)   4672        activation_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_220 (BatchN (None, 11, 11, 64)   256         separable_conv2d_125[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 6, 6, 64)     2048        add_61[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_62 (MaxPooling2D) (None, 6, 6, 64)     0           batch_normalization_220[0][0]
# __________________________________________________________________________________________________
# batch_normalization_218 (BatchN (None, 6, 6, 64)     256         conv2d_109[0][0]
# __________________________________________________________________________________________________
# add_62 (Add)                    (None, 6, 6, 64)     0           max_pooling2d_62[0][0]
#                                                                  batch_normalization_218[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_126 (Separable (None, 6, 6, 128)    8768        add_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_222 (BatchN (None, 6, 6, 128)    512         separable_conv2d_126[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 6, 6, 128)    0           batch_normalization_222[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_127 (Separable (None, 6, 6, 128)    17536       activation_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_223 (BatchN (None, 6, 6, 128)    512         separable_conv2d_127[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 3, 3, 128)    8192        add_62[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_63 (MaxPooling2D) (None, 3, 3, 128)    0           batch_normalization_223[0][0]
# __________________________________________________________________________________________________
# batch_normalization_221 (BatchN (None, 3, 3, 128)    512         conv2d_110[0][0]
# __________________________________________________________________________________________________
# add_63 (Add)                    (None, 3, 3, 128)    0           max_pooling2d_63[0][0]
#                                                                  batch_normalization_221[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 3, 3, 7)      8071        add_63[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_15 (Gl (None, 7)            0           conv2d_111[0][0]
# __________________________________________________________________________________________________
# predictions (Activation)        (None, 7)            0           global_average_pooling2d_15[0][0]
# ==================================================================================================
# Total params: 58,423
# Trainable params: 56,951
# Non-trainable params: 1,472
# __________________________________________________________________________________________________
# Epoch 1/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.9977 - accuracy: 0.3359
# Epoch 00001: val_loss improved from inf to 1.77385, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L2/3/_mini_XCEPTION.01-0.40.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 1.9976 - accuracy: 0.3359 - val_loss: 1.7739 - val_accuracy: 0.3972
# Epoch 2/50
# 898/897 [==============================] - ETA: 0s - loss: 1.5062 - accuracy: 0.4347
# Epoch 00002: val_loss improved from 1.77385 to 1.52682, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L2/3/_mini_XCEPTION.02-0.42.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 1.5062 - accuracy: 0.4347 - val_loss: 1.5268 - val_accuracy: 0.4234
# Epoch 3/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.3949 - accuracy: 0.4838
# Epoch 00003: val_loss improved from 1.52682 to 1.43412, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L2/3/_mini_XCEPTION.03-0.47.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 1.3950 - accuracy: 0.4839 - val_loss: 1.4341 - val_accuracy: 0.4660
# Epoch 4/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.3350 - accuracy: 0.5048
# Epoch 00004: val_loss improved from 1.43412 to 1.30462, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L2/3/_mini_XCEPTION.04-0.52.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 1.3348 - accuracy: 0.5049 - val_loss: 1.3046 - val_accuracy: 0.5212
# Epoch 5/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.2910 - accuracy: 0.5192
# Epoch 00005: val_loss improved from 1.30462 to 1.24142, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L2/3/_mini_XCEPTION.05-0.54.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 1.2907 - accuracy: 0.5193 - val_loss: 1.2414 - val_accuracy: 0.5394
# Epoch 6/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.2584 - accuracy: 0.5289
# Epoch 00006: val_loss did not improve from 1.24142
# 898/897 [==============================] - 19s 21ms/step - loss: 1.2584 - accuracy: 0.5288 - val_loss: 1.3273 - val_accuracy: 0.4954
# Epoch 7/50
# 896/897 [============================>.] - ETA: 0s - loss: 1.2319 - accuracy: 0.5386
# Epoch 00007: val_loss improved from 1.24142 to 1.24013, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L2/3/_mini_XCEPTION.07-0.55.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 1.2321 - accuracy: 0.5387 - val_loss: 1.2401 - val_accuracy: 0.5524
# Epoch 8/50
# 898/897 [==============================] - ETA: 0s - loss: 1.2090 - accuracy: 0.5464
# Epoch 00008: val_loss improved from 1.24013 to 1.19689, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L2/3/_mini_XCEPTION.08-0.55.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 1.2090 - accuracy: 0.5464 - val_loss: 1.1969 - val_accuracy: 0.5468
# Epoch 9/50
# 898/897 [==============================] - ETA: 0s - loss: 1.1905 - accuracy: 0.5549
# Epoch 00009: val_loss did not improve from 1.19689
# 898/897 [==============================] - 18s 21ms/step - loss: 1.1905 - accuracy: 0.5549 - val_loss: 1.2173 - val_accuracy: 0.5499
# Epoch 10/50
# 898/897 [==============================] - ETA: 0s - loss: 1.1692 - accuracy: 0.5590
# Epoch 00010: val_loss improved from 1.19689 to 1.16285, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L2/3/_mini_XCEPTION.10-0.57.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 1.1692 - accuracy: 0.5590 - val_loss: 1.1629 - val_accuracy: 0.5698
# Epoch 11/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.1561 - accuracy: 0.5667
# Epoch 00011: val_loss improved from 1.16285 to 1.11960, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L2/3/_mini_XCEPTION.11-0.58.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 1.1561 - accuracy: 0.5667 - val_loss: 1.1196 - val_accuracy: 0.5839
# Epoch 12/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.1421 - accuracy: 0.5751
# Epoch 00012: val_loss did not improve from 1.11960
# 898/897 [==============================] - 19s 21ms/step - loss: 1.1423 - accuracy: 0.5750 - val_loss: 1.1449 - val_accuracy: 0.5798
# Epoch 13/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.1335 - accuracy: 0.5744
# Epoch 00013: val_loss improved from 1.11960 to 1.10261, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L2/3/_mini_XCEPTION.13-0.59.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 1.1336 - accuracy: 0.5743 - val_loss: 1.1026 - val_accuracy: 0.5899
# Epoch 14/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.1208 - accuracy: 0.5835
# Epoch 00014: val_loss did not improve from 1.10261
# 898/897 [==============================] - 19s 21ms/step - loss: 1.1213 - accuracy: 0.5833 - val_loss: 1.3410 - val_accuracy: 0.5103
# Epoch 15/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.1186 - accuracy: 0.5841
# Epoch 00015: val_loss did not improve from 1.10261
# 898/897 [==============================] - 19s 21ms/step - loss: 1.1188 - accuracy: 0.5840 - val_loss: 1.1223 - val_accuracy: 0.5830
# Epoch 16/50
# 896/897 [============================>.] - ETA: 0s - loss: 1.1064 - accuracy: 0.5873
# Epoch 00016: val_loss did not improve from 1.10261
# 898/897 [==============================] - 19s 21ms/step - loss: 1.1063 - accuracy: 0.5873 - val_loss: 1.1046 - val_accuracy: 0.5961
# Epoch 17/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.1000 - accuracy: 0.5894
# Epoch 00017: val_loss did not improve from 1.10261
# 898/897 [==============================] - 19s 21ms/step - loss: 1.0997 - accuracy: 0.5895 - val_loss: 1.1790 - val_accuracy: 0.5747
# Epoch 18/50
# 898/897 [==============================] - ETA: 0s - loss: 1.0900 - accuracy: 0.5935
# Epoch 00018: val_loss did not improve from 1.10261
# 898/897 [==============================] - 19s 21ms/step - loss: 1.0900 - accuracy: 0.5935 - val_loss: 1.1597 - val_accuracy: 0.5652
# Epoch 19/50
# 898/897 [==============================] - ETA: 0s - loss: 1.0861 - accuracy: 0.5948
# Epoch 00019: val_loss did not improve from 1.10261
# 898/897 [==============================] - 19s 21ms/step - loss: 1.0861 - accuracy: 0.5948 - val_loss: 1.1523 - val_accuracy: 0.5826
# Epoch 20/50
# 898/897 [==============================] - ETA: 0s - loss: 1.0761 - accuracy: 0.5965
# Epoch 00020: val_loss improved from 1.10261 to 1.07821, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L2/3/_mini_XCEPTION.20-0.60.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 1.0761 - accuracy: 0.5965 - val_loss: 1.0782 - val_accuracy: 0.6042
# Epoch 21/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.0693 - accuracy: 0.6018
# Epoch 00021: val_loss did not improve from 1.07821
# 898/897 [==============================] - 19s 21ms/step - loss: 1.0693 - accuracy: 0.6018 - val_loss: 1.2229 - val_accuracy: 0.5497
# Epoch 22/50
# 896/897 [============================>.] - ETA: 0s - loss: 1.0599 - accuracy: 0.6047
# Epoch 00022: val_loss did not improve from 1.07821
# 898/897 [==============================] - 19s 21ms/step - loss: 1.0598 - accuracy: 0.6047 - val_loss: 1.0812 - val_accuracy: 0.5950
# Epoch 23/50
# 896/897 [============================>.] - ETA: 0s - loss: 1.0573 - accuracy: 0.6059
# Epoch 00023: val_loss improved from 1.07821 to 1.07433, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L2/3/_mini_XCEPTION.23-0.60.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 1.0568 - accuracy: 0.6062 - val_loss: 1.0743 - val_accuracy: 0.5992
# Epoch 24/50
# 898/897 [==============================] - ETA: 0s - loss: 1.0493 - accuracy: 0.6075
# Epoch 00024: val_loss did not improve from 1.07433
# 898/897 [==============================] - 19s 21ms/step - loss: 1.0493 - accuracy: 0.6075 - val_loss: 1.0943 - val_accuracy: 0.5971
# Epoch 25/50
# 896/897 [============================>.] - ETA: 0s - loss: 1.0438 - accuracy: 0.6097
# Epoch 00025: val_loss did not improve from 1.07433
# 898/897 [==============================] - 19s 21ms/step - loss: 1.0436 - accuracy: 0.6097 - val_loss: 1.1373 - val_accuracy: 0.5794
# Epoch 26/50
# 898/897 [==============================] - ETA: 0s - loss: 1.0387 - accuracy: 0.6100
# Epoch 00026: val_loss did not improve from 1.07433
# 898/897 [==============================] - 19s 21ms/step - loss: 1.0387 - accuracy: 0.6100 - val_loss: 1.1414 - val_accuracy: 0.5769
# Epoch 27/50
# 896/897 [============================>.] - ETA: 0s - loss: 1.0376 - accuracy: 0.6105
# Epoch 00027: val_loss did not improve from 1.07433
# 898/897 [==============================] - 18s 21ms/step - loss: 1.0378 - accuracy: 0.6105 - val_loss: 1.1529 - val_accuracy: 0.5712
# Epoch 28/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.0339 - accuracy: 0.6134
# Epoch 00028: val_loss did not improve from 1.07433
# 898/897 [==============================] - 19s 21ms/step - loss: 1.0342 - accuracy: 0.6134 - val_loss: 1.0914 - val_accuracy: 0.5903
# Epoch 29/50
# 898/897 [==============================] - ETA: 0s - loss: 1.0267 - accuracy: 0.6195
# Epoch 00029: val_loss did not improve from 1.07433
# 898/897 [==============================] - 19s 21ms/step - loss: 1.0267 - accuracy: 0.6195 - val_loss: 1.1427 - val_accuracy: 0.5737
# Epoch 30/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.0254 - accuracy: 0.6190
# Epoch 00030: val_loss did not improve from 1.07433
# 898/897 [==============================] - 19s 21ms/step - loss: 1.0254 - accuracy: 0.6189 - val_loss: 1.1163 - val_accuracy: 0.5945
# Epoch 31/50
# 896/897 [============================>.] - ETA: 0s - loss: 1.0197 - accuracy: 0.6197
# Epoch 00031: val_loss did not improve from 1.07433
# 898/897 [==============================] - 19s 21ms/step - loss: 1.0195 - accuracy: 0.6198 - val_loss: 1.1082 - val_accuracy: 0.5952
# Epoch 32/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.0196 - accuracy: 0.6189
# Epoch 00032: val_loss did not improve from 1.07433
# 898/897 [==============================] - 18s 21ms/step - loss: 1.0195 - accuracy: 0.6190 - val_loss: 1.0999 - val_accuracy: 0.5886
# Epoch 33/50
# 898/897 [==============================] - ETA: 0s - loss: 1.0139 - accuracy: 0.6209
# Epoch 00033: val_loss did not improve from 1.07433
# 898/897 [==============================] - 19s 21ms/step - loss: 1.0139 - accuracy: 0.6209 - val_loss: 1.0960 - val_accuracy: 0.5904
# Epoch 34/50
# 897/897 [============================>.] - ETA: 0s - loss: 1.0106 - accuracy: 0.6220
# Epoch 00034: val_loss did not improve from 1.07433
# 898/897 [==============================] - 19s 21ms/step - loss: 1.0106 - accuracy: 0.6221 - val_loss: 1.2395 - val_accuracy: 0.5502
# Epoch 35/50
# 898/897 [==============================] - ETA: 0s - loss: 1.0042 - accuracy: 0.6233
# Epoch 00035: val_loss did not improve from 1.07433
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 898/897 [==============================] - 19s 21ms/step - loss: 1.0042 - accuracy: 0.6233 - val_loss: 1.0812 - val_accuracy: 0.6009
# Epoch 36/50
# 896/897 [============================>.] - ETA: 0s - loss: 0.9553 - accuracy: 0.6457
# Epoch 00036: val_loss improved from 1.07433 to 0.99598, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L2/3/_mini_XCEPTION.36-0.63.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 0.9550 - accuracy: 0.6459 - val_loss: 0.9960 - val_accuracy: 0.6266
# Epoch 37/50
# 897/897 [============================>.] - ETA: 0s - loss: 0.9386 - accuracy: 0.6510
# Epoch 00037: val_loss did not improve from 0.99598
# 898/897 [==============================] - 19s 21ms/step - loss: 0.9387 - accuracy: 0.6510 - val_loss: 0.9990 - val_accuracy: 0.6310
# Epoch 38/50
# 898/897 [==============================] - ETA: 0s - loss: 0.9292 - accuracy: 0.6538
# Epoch 00038: val_loss improved from 0.99598 to 0.99203, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L2/3/_mini_XCEPTION.38-0.64.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 0.9292 - accuracy: 0.6538 - val_loss: 0.9920 - val_accuracy: 0.6357
# Epoch 39/50
# 896/897 [============================>.] - ETA: 0s - loss: 0.9239 - accuracy: 0.6545
# Epoch 00039: val_loss did not improve from 0.99203
# 898/897 [==============================] - 18s 21ms/step - loss: 0.9237 - accuracy: 0.6547 - val_loss: 0.9980 - val_accuracy: 0.6255
# Epoch 40/50
# 896/897 [============================>.] - ETA: 0s - loss: 0.9214 - accuracy: 0.6576
# Epoch 00040: val_loss improved from 0.99203 to 0.98557, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L2/3/_mini_XCEPTION.40-0.63.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 0.9213 - accuracy: 0.6576 - val_loss: 0.9856 - val_accuracy: 0.6325
# Epoch 41/50
# 896/897 [============================>.] - ETA: 0s - loss: 0.9194 - accuracy: 0.6570
# Epoch 00041: val_loss did not improve from 0.98557
# 898/897 [==============================] - 19s 21ms/step - loss: 0.9194 - accuracy: 0.6568 - val_loss: 1.0040 - val_accuracy: 0.6199
# Epoch 42/50
# 896/897 [============================>.] - ETA: 0s - loss: 0.9195 - accuracy: 0.6570
# Epoch 00042: val_loss did not improve from 0.98557
# 898/897 [==============================] - 18s 20ms/step - loss: 0.9198 - accuracy: 0.6570 - val_loss: 0.9912 - val_accuracy: 0.6308
# Epoch 43/50
# 897/897 [============================>.] - ETA: 0s - loss: 0.9173 - accuracy: 0.6587
# Epoch 00043: val_loss did not improve from 0.98557
# 898/897 [==============================] - 19s 21ms/step - loss: 0.9173 - accuracy: 0.6587 - val_loss: 1.0013 - val_accuracy: 0.6311
# Epoch 44/50
# 896/897 [============================>.] - ETA: 0s - loss: 0.9098 - accuracy: 0.6617
# Epoch 00044: val_loss improved from 0.98557 to 0.97943, saving model to /content/drive/MyDrive/석사 2학기/Data Analysis/Term Project/Final/실험 정리/regularization 실험/L2/3/_mini_XCEPTION.44-0.64.hdf5
# 898/897 [==============================] - 19s 21ms/step - loss: 0.9100 - accuracy: 0.6615 - val_loss: 0.9794 - val_accuracy: 0.6367
# Epoch 45/50
# 897/897 [============================>.] - ETA: 0s - loss: 0.9110 - accuracy: 0.6581
# Epoch 00045: val_loss did not improve from 0.97943
# 898/897 [==============================] - 19s 21ms/step - loss: 0.9112 - accuracy: 0.6581 - val_loss: 0.9882 - val_accuracy: 0.6315
# Epoch 46/50
# 897/897 [============================>.] - ETA: 0s - loss: 0.9088 - accuracy: 0.6618
# Epoch 00046: val_loss did not improve from 0.97943
# 898/897 [==============================] - 19s 21ms/step - loss: 0.9087 - accuracy: 0.6619 - val_loss: 0.9967 - val_accuracy: 0.6273
# Epoch 47/50
# 896/897 [============================>.] - ETA: 0s - loss: 0.9009 - accuracy: 0.6617
# Epoch 00047: val_loss did not improve from 0.97943
# 898/897 [==============================] - 19s 21ms/step - loss: 0.9009 - accuracy: 0.6616 - val_loss: 0.9957 - val_accuracy: 0.6291
# Epoch 48/50
# 897/897 [============================>.] - ETA: 0s - loss: 0.9062 - accuracy: 0.6616
# Epoch 00048: val_loss did not improve from 0.97943
# 898/897 [==============================] - 18s 21ms/step - loss: 0.9061 - accuracy: 0.6617 - val_loss: 0.9905 - val_accuracy: 0.6308
# Epoch 49/50
# 896/897 [============================>.] - ETA: 0s - loss: 0.9029 - accuracy: 0.6614
# Epoch 00049: val_loss did not improve from 0.97943
# 898/897 [==============================] - 18s 20ms/step - loss: 0.9027 - accuracy: 0.6616 - val_loss: 0.9834 - val_accuracy: 0.6312
# Epoch 50/50
# 896/897 [============================>.] - ETA: 0s - loss: 0.9042 - accuracy: 0.6615
# Epoch 00050: val_loss did not improve from 0.97943
# 898/897 [==============================] - 18s 21ms/step - loss: 0.9043 - accuracy: 0.6614 - val_loss: 0.9837 - val_accuracy: 0.6333

# %%
plt_path = base_path + 'plt.png'
#learning curve
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
#plt.show()

plt.savefig(plt_path)

# %%
import matplotlib.pyplot as plt

fig_path = base_path + 'fig_acc_loss.png'
def plot_model_performance(train_loss, train_acc, train_val_loss, train_val_acc):
    """ Plot model loss and accuracy through epochs. """
    blue= '#34495E'
    green = '#2ECC71'
    orange = '#E23B13'
    
    # Loss plot model (손실)
    fig, (ax1, ax2) = plt.subplots(2, figsize=(10, 8))
    ax1.plot(range(1, len(train_loss) + 1), train_loss, blue, linewidth=5, label='training')
    ax1.plot(range(1, len(train_val_loss) + 1), train_val_loss, green, linewidth=5, label='validation')
    ax1.set_xlabel('# epoch')
    ax1.set_ylabel('loss')
    ax1.tick_params('y')
    ax1.legend(loc='upper right', shadow=False)
    ax1.set_title('Model loss through #epochs', color=orange, fontweight='bold')
    
    # Accuracy plot model (정확도)
    ax2.plot(range(1, len(train_acc) + 1), train_acc, blue, linewidth=5, label='training')
    ax2.plot(range(1, len(train_val_acc) + 1), train_val_acc, green, linewidth=5, label='validation')
    ax2.set_xlabel('# epoch')
    ax2.set_ylabel('accuracy')
    ax2.tick_params('y')
    ax2.legend(loc='lower right', shadow=False)
    ax2.set_title('Model accuracy through #epochs', color=orange, fontweight='bold')
    fig.savefig(fig_path)

# %%
fig = plot_model_performance(
    train_loss=history.history.get('loss', []),
    train_acc=history.history.get('accuracy', []),
    train_val_loss=history.history.get('val_loss', []),
    train_val_acc=history.history.get('val_accuracy', [])
)
