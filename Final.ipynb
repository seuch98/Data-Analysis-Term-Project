# %%
import pandas as pd
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

#dataset_path = 'fer2013.csv'
dataset_path = 'C:\\Users\\User\\Desktop\\CW\\DA\\Term Project\\fer2013.csv'
image_size=(48,48)

#csv 파일 읽어서 48*48 크기의 이미지에서 각 행의 픽셀 시퀀스 변환. 얼굴과 감정 레이블 반환

def load_fer2013():
    data = pd.read_csv(dataset_path)
    pixels = data['pixels'].tolist()
    width, height = 48, 48
    faces = []
    for pixel_sequence in pixels:
        face = [int(pixel) for pixel in pixel_sequence.split(' ')]
        face = np.asarray(face).reshape(width, height)
        face = cv2.resize(face.astype('uint8'),image_size)
        faces.append(face.astype('float32'))
    faces = np.asarray(faces)
    faces = np.expand_dims(faces, -1)
    emotions = pd.get_dummies(data['emotion']).values
    return faces, emotions

#이미지를 -1에서 1 사이의 크기로 조정하여 이미지를 전처리하는 표준 방법.
#이미지의 크기를 [0,1]로 255 나눠서 조정.
#0.5를 빼고 2를 곱하면 범위가 [-1,1]로 바뀜. 이건 컴퓨터 비전 문제에서 신경 네트워크 모델에 대한 더 나은 범위

def preprocess_input(x, v2=True):
    x = x.astype('float32') #######
    x = x / 255.0
    if v2:
        x = x - 0.5
        x = x * 2.0
    return x
 
faces, emotions = load_fer2013()
faces = preprocess_input(faces)
xtrain, xtest,ytrain,ytest = train_test_split(faces, emotions,test_size=0.2,shuffle=True, random_state=1004)

# %%
from keras.callbacks import CSVLogger, ModelCheckpoint, EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from keras.layers import Activation, Convolution2D, Dropout, Conv2D
from keras.layers import AveragePooling2D, BatchNormalization
from keras.layers import GlobalAveragePooling2D
from keras.models import Sequential
from keras.layers import Flatten
from keras.models import Model
from keras.layers import Input
from keras.layers import MaxPooling2D
from keras.layers import SeparableConv2D
from keras import layers
from keras.regularizers import l2
import pandas as pd
import cv2
import numpy as np
 
# parameters
batch_size = 32
num_epochs = 70 
input_shape = (48, 48, 1)
verbose = 1
num_classes = 7
patience = 50
base_path = 'C:\\Users\\User\\Desktop\\CW\\DA\\Term Project\\Final\\'
#base_path = './models/'
l2_regularization=0.08
 
# data generator
data_generator = ImageDataGenerator(
                        featurewise_center=False,
                        featurewise_std_normalization=False,
                        rotation_range=10,
                        width_shift_range=0.1,
                        height_shift_range=0.1,
                        zoom_range=.1,
                        horizontal_flip=True)
 
# model parameters
regularization = l2(l2_regularization)
 
# base
img_input = Input(input_shape)
x = Conv2D(8, (3, 3), strides=(1, 1), kernel_regularizer=regularization, use_bias=False)(img_input)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Conv2D(8, (3, 3), strides=(1, 1), kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
 
# module 1
residual = Conv2D(16, (1, 1), strides=(2, 2), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(16, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(16, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
 
# module 2
residual = Conv2D(32, (1, 1), strides=(2, 2), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(32, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(32, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
 
# module 3
residual = Conv2D(64, (1, 1), strides=(2, 2),padding='same', kernel_regularizer=regularization, use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(64, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(64, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
 
# module 4
residual = Conv2D(128, (1, 1), strides=(2, 2),padding='same', kernel_regularizer=regularization, use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(128, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(128, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
x = Conv2D(num_classes, (3, 3), padding='same')(x)
x = GlobalAveragePooling2D()(x)
output = Activation('softmax',name='predictions')(x)
 
model = Model(img_input, output)
model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
 
# callbacks
log_file_path = base_path + '_emotion_training.log'
csv_logger = CSVLogger(log_file_path, append=False)
early_stop = EarlyStopping('val_loss', patience=patience)
reduce_lr = ReduceLROnPlateau('val_loss', factor=0.1, patience=int(patience/4), verbose=1)
trained_models_path = base_path + '_mini_XCEPTION'
model_names = trained_models_path + '.{epoch:02d}-{val_accuracy:.2f}.hdf5'
model_checkpoint = ModelCheckpoint(model_names, 'val_loss', verbose=1,save_best_only=True)
callbacks = [model_checkpoint, csv_logger, early_stop, reduce_lr]
 
history= model.fit_generator(data_generator.flow(xtrain, ytrain,batch_size),
                        steps_per_epoch=len(xtrain) / batch_size,
                        epochs=num_epochs, verbose=1, callbacks=callbacks,
                        validation_data=(xtest,ytest))
# Out:
# Using TensorFlow backend.
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 48, 48, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 46, 46, 8)    72          input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 46, 46, 8)    32          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 46, 46, 8)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 44, 44, 8)    576         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 44, 44, 8)    32          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 44, 44, 8)    0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 44, 44, 16)   200         activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 44, 44, 16)   64          separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 44, 44, 16)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 44, 44, 16)   400         activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 44, 44, 16)   64          separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 22, 22, 16)   128         activation_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 22, 22, 16)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 22, 22, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 22, 22, 16)   0           max_pooling2d_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 22, 22, 32)   656         add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 22, 22, 32)   128         separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 22, 22, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 22, 22, 32)   1312        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 22, 22, 32)   128         separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 11, 11, 32)   512         add_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 11, 11, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 11, 11, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 11, 11, 32)   0           max_pooling2d_2[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 11, 11, 64)   2336        add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 11, 11, 64)   256         separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 11, 11, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 11, 11, 64)   4672        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 11, 11, 64)   256         separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 6, 6, 64)     2048        add_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 6, 6, 64)     0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 6, 6, 64)     256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 6, 6, 64)     0           max_pooling2d_3[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_7 (SeparableCo (None, 6, 6, 128)    8768        add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 6, 6, 128)    512         separable_conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 6, 6, 128)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_8 (SeparableCo (None, 6, 6, 128)    17536       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 6, 6, 128)    512         separable_conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 3, 3, 128)    8192        add_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 3, 3, 128)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 3, 3, 128)    512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 3, 3, 128)    0           max_pooling2d_4[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 3, 3, 7)      8071        add_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 7)            0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# predictions (Activation)        (None, 7)            0           global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 58,423
# Trainable params: 56,951
# Non-trainable params: 1,472
# __________________________________________________________________________________________________
# Epoch 1/70
# 898/897 [==============================] - 26s 29ms/step - loss: 3.1963 - accuracy: 0.3313 - val_loss: 1.7660 - val_accuracy: 0.3615
#
# Epoch 00001: val_loss improved from inf to 1.76600, saving model to C:\Users\User\Desktop\CW\DA\Term Project\Final\_mini_XCEPTION.01-0.36.hdf5
# Epoch 2/70
# 898/897 [==============================] - 22s 24ms/step - loss: 1.5325 - accuracy: 0.4443 - val_loss: 1.6666 - val_accuracy: 0.3898
#
# Epoch 00002: val_loss improved from 1.76600 to 1.66658, saving model to C:\Users\User\Desktop\CW\DA\Term Project\Final\_mini_XCEPTION.02-0.39.hdf5
# Epoch 3/70
# 898/897 [==============================] - 22s 24ms/step - loss: 1.4351 - accuracy: 0.4809 - val_loss: 1.3846 - val_accuracy: 0.4897
#
# Epoch 00003: val_loss improved from 1.66658 to 1.38463, saving model to C:\Users\User\Desktop\CW\DA\Term Project\Final\_mini_XCEPTION.03-0.49.hdf5
# Epoch 4/70
# 898/897 [==============================] - 22s 25ms/step - loss: 1.3751 - accuracy: 0.4987 - val_loss: 1.6386 - val_accuracy: 0.4267
#
# Epoch 00004: val_loss did not improve from 1.38463
# Epoch 5/70
# 898/897 [==============================] - 22s 24ms/step - loss: 1.3393 - accuracy: 0.5118 - val_loss: 1.6163 - val_accuracy: 0.4420
#
# Epoch 00005: val_loss did not improve from 1.38463
# Epoch 6/70
# 898/897 [==============================] - 22s 25ms/step - loss: 1.3041 - accuracy: 0.5267 - val_loss: 1.3513 - val_accuracy: 0.5180
#
# Epoch 00006: val_loss improved from 1.38463 to 1.35128, saving model to C:\Users\User\Desktop\CW\DA\Term Project\Final\_mini_XCEPTION.06-0.52.hdf5
# Epoch 7/70
# 898/897 [==============================] - 23s 25ms/step - loss: 1.2814 - accuracy: 0.5348 - val_loss: 1.5498 - val_accuracy: 0.4542
#
# Epoch 00007: val_loss did not improve from 1.35128
# Epoch 8/70
# 898/897 [==============================] - 24s 26ms/step - loss: 1.2582 - accuracy: 0.5403 - val_loss: 1.3011 - val_accuracy: 0.5304
#
# Epoch 00008: val_loss improved from 1.35128 to 1.30109, saving model to C:\Users\User\Desktop\CW\DA\Term Project\Final\_mini_XCEPTION.08-0.53.hdf5
# Epoch 9/70
# 898/897 [==============================] - 23s 26ms/step - loss: 1.2403 - accuracy: 0.5502 - val_loss: 1.3132 - val_accuracy: 0.5153
#
# Epoch 00009: val_loss did not improve from 1.30109
# Epoch 10/70
# 898/897 [==============================] - 23s 26ms/step - loss: 1.2221 - accuracy: 0.5560 - val_loss: 1.2600 - val_accuracy: 0.5457
#
# Epoch 00010: val_loss improved from 1.30109 to 1.25996, saving model to C:\Users\User\Desktop\CW\DA\Term Project\Final\_mini_XCEPTION.10-0.55.hdf5
# Epoch 11/70
# 898/897 [==============================] - 23s 26ms/step - loss: 1.2013 - accuracy: 0.5609 - val_loss: 1.2708 - val_accuracy: 0.5284
#
# Epoch 00011: val_loss did not improve from 1.25996
# Epoch 12/70
# 898/897 [==============================] - 24s 27ms/step - loss: 1.1839 - accuracy: 0.5655 - val_loss: 1.2359 - val_accuracy: 0.5350
#
# Epoch 00012: val_loss improved from 1.25996 to 1.23589, saving model to C:\Users\User\Desktop\CW\DA\Term Project\Final\_mini_XCEPTION.12-0.53.hdf5
# Epoch 13/70
# 898/897 [==============================] - 24s 26ms/step - loss: 1.1660 - accuracy: 0.5727 - val_loss: 1.1979 - val_accuracy: 0.5698
#
# Epoch 00013: val_loss improved from 1.23589 to 1.19794, saving model to C:\Users\User\Desktop\CW\DA\Term Project\Final\_mini_XCEPTION.13-0.57.hdf5
# Epoch 14/70
# 898/897 [==============================] - 23s 26ms/step - loss: 1.1616 - accuracy: 0.5768 - val_loss: 1.2404 - val_accuracy: 0.5560
#
# Epoch 00014: val_loss did not improve from 1.19794
# Epoch 15/70
# 898/897 [==============================] - 23s 25ms/step - loss: 1.1471 - accuracy: 0.5786 - val_loss: 1.1259 - val_accuracy: 0.5809
#
# Epoch 00015: val_loss improved from 1.19794 to 1.12592, saving model to C:\Users\User\Desktop\CW\DA\Term Project\Final\_mini_XCEPTION.15-0.58.hdf5
# Epoch 16/70
# 898/897 [==============================] - 23s 26ms/step - loss: 1.1312 - accuracy: 0.5816 - val_loss: 1.2065 - val_accuracy: 0.5641
#
# Epoch 00016: val_loss did not improve from 1.12592
# Epoch 17/70
# 898/897 [==============================] - 23s 25ms/step - loss: 1.1259 - accuracy: 0.5863 - val_loss: 1.1313 - val_accuracy: 0.5894
#
# Epoch 00017: val_loss did not improve from 1.12592
# Epoch 18/70
# 898/897 [==============================] - 24s 27ms/step - loss: 1.1107 - accuracy: 0.5954 - val_loss: 1.1707 - val_accuracy: 0.5708
#
# Epoch 00018: val_loss did not improve from 1.12592
# Epoch 19/70
# 898/897 [==============================] - 23s 26ms/step - loss: 1.1038 - accuracy: 0.5948 - val_loss: 1.2008 - val_accuracy: 0.5669
#
# Epoch 00019: val_loss did not improve from 1.12592
# Epoch 20/70
# 898/897 [==============================] - 23s 26ms/step - loss: 1.0905 - accuracy: 0.5988 - val_loss: 1.1417 - val_accuracy: 0.5684
#
# Epoch 00020: val_loss did not improve from 1.12592
# Epoch 21/70
# 898/897 [==============================] - 24s 26ms/step - loss: 1.0861 - accuracy: 0.5933 - val_loss: 1.1005 - val_accuracy: 0.5952
#
# Epoch 00021: val_loss improved from 1.12592 to 1.10051, saving model to C:\Users\User\Desktop\CW\DA\Term Project\Final\_mini_XCEPTION.21-0.60.hdf5
# Epoch 22/70
# 898/897 [==============================] - 24s 26ms/step - loss: 1.0772 - accuracy: 0.6046 - val_loss: 1.0747 - val_accuracy: 0.6119
#
# Epoch 00022: val_loss improved from 1.10051 to 1.07473, saving model to C:\Users\User\Desktop\CW\DA\Term Project\Final\_mini_XCEPTION.22-0.61.hdf5
# Epoch 23/70
# 898/897 [==============================] - 23s 26ms/step - loss: 1.0799 - accuracy: 0.6005 - val_loss: 1.1083 - val_accuracy: 0.5833
#
# Epoch 00023: val_loss did not improve from 1.07473
# Epoch 24/70
# 898/897 [==============================] - 23s 26ms/step - loss: 1.0651 - accuracy: 0.6090 - val_loss: 1.1138 - val_accuracy: 0.5885
#
# Epoch 00024: val_loss did not improve from 1.07473
# Epoch 25/70
# 898/897 [==============================] - 23s 26ms/step - loss: 1.0602 - accuracy: 0.6080 - val_loss: 1.1071 - val_accuracy: 0.5931
#
# Epoch 00025: val_loss did not improve from 1.07473
# Epoch 26/70
# 898/897 [==============================] - 23s 25ms/step - loss: 1.0575 - accuracy: 0.6094 - val_loss: 1.1240 - val_accuracy: 0.5876
#
# Epoch 00026: val_loss did not improve from 1.07473
# Epoch 27/70
# 898/897 [==============================] - 23s 26ms/step - loss: 1.0510 - accuracy: 0.6074 - val_loss: 1.0954 - val_accuracy: 0.5981
#
# Epoch 00027: val_loss did not improve from 1.07473
# Epoch 28/70
# 898/897 [==============================] - 23s 26ms/step - loss: 1.0470 - accuracy: 0.6111 - val_loss: 1.1452 - val_accuracy: 0.5729
#
# Epoch 00028: val_loss did not improve from 1.07473
# Epoch 29/70
# 898/897 [==============================] - 23s 26ms/step - loss: 1.0397 - accuracy: 0.6126 - val_loss: 1.0894 - val_accuracy: 0.5991
#
# Epoch 00029: val_loss did not improve from 1.07473
# Epoch 30/70
# 898/897 [==============================] - 23s 26ms/step - loss: 1.0320 - accuracy: 0.6171 - val_loss: 1.0926 - val_accuracy: 0.5981
#
# Epoch 00030: val_loss did not improve from 1.07473
# Epoch 31/70
# 898/897 [==============================] - 23s 26ms/step - loss: 1.0290 - accuracy: 0.6148 - val_loss: 1.0741 - val_accuracy: 0.6089
#
# Epoch 00031: val_loss improved from 1.07473 to 1.07410, saving model to C:\Users\User\Desktop\CW\DA\Term Project\Final\_mini_XCEPTION.31-0.61.hdf5
# Epoch 32/70
# 898/897 [==============================] - 22s 25ms/step - loss: 1.0243 - accuracy: 0.6188 - val_loss: 1.0713 - val_accuracy: 0.6014
#
# Epoch 00032: val_loss improved from 1.07410 to 1.07129, saving model to C:\Users\User\Desktop\CW\DA\Term Project\Final\_mini_XCEPTION.32-0.60.hdf5
# Epoch 33/70
# 898/897 [==============================] - 23s 26ms/step - loss: 1.0240 - accuracy: 0.6226 - val_loss: 1.0727 - val_accuracy: 0.6037
#
# Epoch 00033: val_loss did not improve from 1.07129
# Epoch 34/70
# 898/897 [==============================] - 24s 27ms/step - loss: 1.0121 - accuracy: 0.6271 - val_loss: 1.0699 - val_accuracy: 0.6116
#
# Epoch 00034: val_loss improved from 1.07129 to 1.06986, saving model to C:\Users\User\Desktop\CW\DA\Term Project\Final\_mini_XCEPTION.34-0.61.hdf5
# Epoch 35/70
# 898/897 [==============================] - 23s 26ms/step - loss: 1.0144 - accuracy: 0.6249 - val_loss: 1.1511 - val_accuracy: 0.5630
#
# Epoch 00035: val_loss did not improve from 1.06986
# Epoch 36/70
# 898/897 [==============================] - 23s 26ms/step - loss: 1.0091 - accuracy: 0.6242 - val_loss: 1.0898 - val_accuracy: 0.5986
#
# Epoch 00036: val_loss did not improve from 1.06986
# Epoch 37/70
# 898/897 [==============================] - 23s 26ms/step - loss: 1.0084 - accuracy: 0.6274 - val_loss: 1.1310 - val_accuracy: 0.5880
#
# Epoch 00037: val_loss did not improve from 1.06986
# Epoch 38/70
# 898/897 [==============================] - 23s 26ms/step - loss: 1.0014 - accuracy: 0.6290 - val_loss: 1.1228 - val_accuracy: 0.5893
#
# Epoch 00038: val_loss did not improve from 1.06986
# Epoch 39/70
# 898/897 [==============================] - 24s 26ms/step - loss: 1.0038 - accuracy: 0.6277 - val_loss: 1.1055 - val_accuracy: 0.5946
#
# Epoch 00039: val_loss did not improve from 1.06986
# Epoch 40/70
# 898/897 [==============================] - 24s 26ms/step - loss: 0.9970 - accuracy: 0.6291 - val_loss: 1.0399 - val_accuracy: 0.6162
#
# Epoch 00040: val_loss improved from 1.06986 to 1.03989, saving model to C:\Users\User\Desktop\CW\DA\Term Project\Final\_mini_XCEPTION.40-0.62.hdf5
# Epoch 41/70
# 898/897 [==============================] - 23s 26ms/step - loss: 0.9933 - accuracy: 0.6315 - val_loss: 1.1487 - val_accuracy: 0.5737
#
# Epoch 00041: val_loss did not improve from 1.03989
# Epoch 42/70
# 898/897 [==============================] - 23s 26ms/step - loss: 0.9961 - accuracy: 0.6266 - val_loss: 1.0675 - val_accuracy: 0.6028
#
# Epoch 00042: val_loss did not improve from 1.03989
# Epoch 43/70
# 898/897 [==============================] - 23s 26ms/step - loss: 0.9844 - accuracy: 0.6342 - val_loss: 1.1337 - val_accuracy: 0.5954
#
# Epoch 00043: val_loss did not improve from 1.03989
# Epoch 44/70
# 898/897 [==============================] - 23s 26ms/step - loss: 0.9872 - accuracy: 0.6345 - val_loss: 1.0450 - val_accuracy: 0.6179
#
# Epoch 00044: val_loss did not improve from 1.03989
# Epoch 45/70
# 898/897 [==============================] - 24s 26ms/step - loss: 0.9886 - accuracy: 0.6344 - val_loss: 1.0944 - val_accuracy: 0.5921
#
# Epoch 00045: val_loss did not improve from 1.03989
# Epoch 46/70
# 898/897 [==============================] - 23s 26ms/step - loss: 0.9787 - accuracy: 0.6389 - val_loss: 1.0415 - val_accuracy: 0.6234
#
# Epoch 00046: val_loss did not improve from 1.03989
# Epoch 47/70
# 898/897 [==============================] - 23s 25ms/step - loss: 0.9747 - accuracy: 0.6401 - val_loss: 1.0760 - val_accuracy: 0.6123
#
# Epoch 00047: val_loss did not improve from 1.03989
# Epoch 48/70
# 898/897 [==============================] - 24s 26ms/step - loss: 0.9765 - accuracy: 0.6373 - val_loss: 1.0563 - val_accuracy: 0.6208
#
# Epoch 00048: val_loss did not improve from 1.03989
# Epoch 49/70
# 898/897 [==============================] - 23s 26ms/step - loss: 0.9756 - accuracy: 0.6405 - val_loss: 1.0580 - val_accuracy: 0.6232
#
# Epoch 00049: val_loss did not improve from 1.03989
# Epoch 50/70
# 898/897 [==============================] - 24s 26ms/step - loss: 0.9681 - accuracy: 0.6418 - val_loss: 1.0630 - val_accuracy: 0.6187
#
# Epoch 00050: val_loss did not improve from 1.03989
# Epoch 51/70
# 898/897 [==============================] - 24s 26ms/step - loss: 0.9654 - accuracy: 0.6442 - val_loss: 1.0630 - val_accuracy: 0.6145
#
# Epoch 00051: val_loss did not improve from 1.03989
# Epoch 52/70
# 898/897 [==============================] - 24s 26ms/step - loss: 0.9668 - accuracy: 0.6411 - val_loss: 1.0559 - val_accuracy: 0.6230
#
# Epoch 00052: val_loss did not improve from 1.03989
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 53/70
# 898/897 [==============================] - 24s 26ms/step - loss: 0.9158 - accuracy: 0.6615 - val_loss: 0.9826 - val_accuracy: 0.6406
#
# Epoch 00053: val_loss improved from 1.03989 to 0.98260, saving model to C:\Users\User\Desktop\CW\DA\Term Project\Final\_mini_XCEPTION.53-0.64.hdf5
# Epoch 54/70
# 898/897 [==============================] - 23s 26ms/step - loss: 0.8975 - accuracy: 0.6687 - val_loss: 0.9706 - val_accuracy: 0.6431
#
# Epoch 00054: val_loss improved from 0.98260 to 0.97064, saving model to C:\Users\User\Desktop\CW\DA\Term Project\Final\_mini_XCEPTION.54-0.64.hdf5
# Epoch 55/70
# 898/897 [==============================] - 23s 26ms/step - loss: 0.8945 - accuracy: 0.6691 - val_loss: 0.9746 - val_accuracy: 0.6417
#
# Epoch 00055: val_loss did not improve from 0.97064
# Epoch 56/70
# 898/897 [==============================] - 24s 27ms/step - loss: 0.8908 - accuracy: 0.6690 - val_loss: 0.9842 - val_accuracy: 0.6399
#
# Epoch 00056: val_loss did not improve from 0.97064
# Epoch 57/70
# 898/897 [==============================] - 23s 26ms/step - loss: 0.8832 - accuracy: 0.6726 - val_loss: 0.9834 - val_accuracy: 0.6413
#
# Epoch 00057: val_loss did not improve from 0.97064
# Epoch 58/70
# 898/897 [==============================] - 21s 24ms/step - loss: 0.8886 - accuracy: 0.6699 - val_loss: 0.9698 - val_accuracy: 0.6445
#
# Epoch 00058: val_loss improved from 0.97064 to 0.96977, saving model to C:\Users\User\Desktop\CW\DA\Term Project\Final\_mini_XCEPTION.58-0.64.hdf5
# Epoch 59/70
# 898/897 [==============================] - 21s 24ms/step - loss: 0.8815 - accuracy: 0.6716 - val_loss: 0.9697 - val_accuracy: 0.6439
#
# Epoch 00059: val_loss improved from 0.96977 to 0.96970, saving model to C:\Users\User\Desktop\CW\DA\Term Project\Final\_mini_XCEPTION.59-0.64.hdf5
# Epoch 60/70
# 898/897 [==============================] - 21s 24ms/step - loss: 0.8737 - accuracy: 0.6730 - val_loss: 0.9851 - val_accuracy: 0.6360
#
# Epoch 00060: val_loss did not improve from 0.96970
# Epoch 61/70
# 898/897 [==============================] - 22s 24ms/step - loss: 0.8819 - accuracy: 0.6710 - val_loss: 0.9729 - val_accuracy: 0.6417
#
# Epoch 00061: val_loss did not improve from 0.96970
# Epoch 62/70
# 898/897 [==============================] - 22s 24ms/step - loss: 0.8707 - accuracy: 0.6750 - val_loss: 0.9655 - val_accuracy: 0.6460
#
# Epoch 00062: val_loss improved from 0.96970 to 0.96546, saving model to C:\Users\User\Desktop\CW\DA\Term Project\Final\_mini_XCEPTION.62-0.65.hdf5
# Epoch 63/70
# 898/897 [==============================] - 22s 24ms/step - loss: 0.8748 - accuracy: 0.6747 - val_loss: 0.9787 - val_accuracy: 0.6402
#
# Epoch 00063: val_loss did not improve from 0.96546
# Epoch 64/70
# 898/897 [==============================] - 22s 24ms/step - loss: 0.8745 - accuracy: 0.6718 - val_loss: 0.9698 - val_accuracy: 0.6467
#
# Epoch 00064: val_loss did not improve from 0.96546
# Epoch 65/70
# 898/897 [==============================] - 22s 24ms/step - loss: 0.8674 - accuracy: 0.6785 - val_loss: 0.9720 - val_accuracy: 0.6438
#
# Epoch 00065: val_loss did not improve from 0.96546
# Epoch 66/70
# 898/897 [==============================] - 22s 24ms/step - loss: 0.8669 - accuracy: 0.6782 - val_loss: 0.9703 - val_accuracy: 0.6447
#
# Epoch 00066: val_loss did not improve from 0.96546
# Epoch 67/70
# 898/897 [==============================] - 22s 24ms/step - loss: 0.8652 - accuracy: 0.6780 - val_loss: 0.9731 - val_accuracy: 0.6478
#
# Epoch 00067: val_loss did not improve from 0.96546
# Epoch 68/70
# 898/897 [==============================] - 22s 24ms/step - loss: 0.8700 - accuracy: 0.6776 - val_loss: 0.9707 - val_accuracy: 0.6447
#
# Epoch 00068: val_loss did not improve from 0.96546
# Epoch 69/70
# 898/897 [==============================] - 22s 24ms/step - loss: 0.8657 - accuracy: 0.6773 - val_loss: 0.9783 - val_accuracy: 0.6441
#
# Epoch 00069: val_loss did not improve from 0.96546
# Epoch 70/70
# 898/897 [==============================] - 22s 24ms/step - loss: 0.8637 - accuracy: 0.6795 - val_loss: 0.9720 - val_accuracy: 0.6415
#
# Epoch 00070: val_loss did not improve from 0.96546

# %%
plt_path = base_path + 'plt.png'
#learning curve
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
#plt.show()

plt.savefig(plt_path)

# %%
import matplotlib.pyplot as plt

fig_path = base_path + 'fig_acc_loss.png'
def plot_model_performance(train_loss, train_acc, train_val_loss, train_val_acc):
    """ Plot model loss and accuracy through epochs. """
    blue= '#34495E'
    green = '#2ECC71'
    orange = '#E23B13'
    
    # Loss plot model (손실)
    fig, (ax1, ax2) = plt.subplots(2, figsize=(10, 8))
    ax1.plot(range(1, len(train_loss) + 1), train_loss, blue, linewidth=5, label='training')
    ax1.plot(range(1, len(train_val_loss) + 1), train_val_loss, green, linewidth=5, label='validation')
    ax1.set_xlabel('# epoch')
    ax1.set_ylabel('loss')
    ax1.tick_params('y')
    ax1.legend(loc='upper right', shadow=False)
    ax1.set_title('Model loss through #epochs', color=orange, fontweight='bold')
    
    # Accuracy plot model (정확도)
    ax2.plot(range(1, len(train_acc) + 1), train_acc, blue, linewidth=5, label='training')
    ax2.plot(range(1, len(train_val_acc) + 1), train_val_acc, green, linewidth=5, label='validation')
    ax2.set_xlabel('# epoch')
    ax2.set_ylabel('accuracy')
    ax2.tick_params('y')
    ax2.legend(loc='lower right', shadow=False)
    ax2.set_title('Model accuracy through #epochs', color=orange, fontweight='bold')
    fig.savefig(fig_path)

# %%
fig = plot_model_performance(
    train_loss=history.history.get('loss', []),
    train_acc=history.history.get('accuracy', []),
    train_val_loss=history.history.get('val_loss', []),
    train_val_acc=history.history.get('val_accuracy', [])
)

# %%
# CNN 구조 변경 시 모델 시각화 저장용
from tensorflow.keras.utils import plot_model
model_file_path = base_path + 'CNN.png'
plot_model(model, to_file=model_file_path, show_shapes=True, show_layer_names = True)
